# %% [markdown]
# ### Part 2: Image Processing and Transfer Learning - 50%
# In part 2 of the assignment, we switch from text processing to image processing to explore
# another set of model tasks. Again, you are asked to follow a set of instructions below and report
# on your findings.
#
# For this assignment we will make use of the CIFAR-100 dataset of images.
# - Rather than using all images, you are asked to randomly split CIFAR into two subsets of 50 classes each.
# - Your first task is to make these subsets and save these subsets to disk for use later.
# - Make sure to randomly select these classes (don’t just take the first 50).
# - Also make sure to account for training, validation or test as appropriate.
# - We will refer to the first set of data as Block 1 and the second set of 50 classes as Block 2.
#
# As with Part 1, the set of tasks below do not build on each other and can in some ways be
# considered independent.

# %%
import numpy as np
import pandas as pd
import pickle
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, Flatten, add, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, UpSampling2D, Reshape, Conv2D
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.losses import KLDivergence
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
BASE_DIR_PATH = "./"
MODEL_DIR_PATH = BASE_DIR_PATH + "models/Part2/CNN"
DATA_DIR_PATH = BASE_DIR_PATH + "data/Part2"
TRAIN_DIR_PATH = DATA_DIR_PATH + "/train"
TEST_DIR_PATH = DATA_DIR_PATH + "/test"

# %%
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# normalise the pixel values to be between 0 and 1
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

# Load the CIFAR-100 data
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# Save the CIFAR-100 data
def save_pickle(data, file):
    with open(file, 'wb') as fo:
        pickle.dump(data, fo)

# %%
# display the first 10 images
plt.figure(figsize=(20, 4))
for i in range(5):
    # display original
    ax = plt.subplot(2, 5, i + 1)
    plt.imshow(test_images[i])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# ### Task 1: Load the CIFAR-100 dataset and split it into two sets of 50 classes each.

# %% [markdown]
# #### Randomly select 50 classes for Block 1 and 50 classes for Block 2.

# %%
# The CIFAR-100 dataset has 100 classes
num_classes = 100
np.random.seed(42)
classes = np.arange(num_classes)
np.random.shuffle(classes)

# %%
# Split the class indices into two subsets of 50 classes each
block_1_classes = classes[:50]
block_2_classes = classes[50:]

# %% [markdown]
# #### Filter the dataset to only include the selected classes for each block.

# %%
def filter_by_classes(images, labels, class_subset):
    """
    Filters images and labels by a subset of classes.

    Args:
        images (numpy.ndarray): Array of images.
        labels (numpy.ndarray): Array of labels corresponding to the images.
        class_subset (list or numpy.ndarray): List or array of class labels to filter by.

    Returns:
        tuple: A tuple containing:
            - filtered_images (numpy.ndarray): Array of images filtered by the specified classes.
            - filtered_labels (numpy.ndarray): Array of labels filtered by the specified classes.
    """
    indices = np.isin(labels, class_subset)
    filtered_images = images[indices.flatten()]
    filtered_labels = labels[indices.flatten()]
    return filtered_images, filtered_labels

# %%
def remap_labels(labels, class_subset):
    """
    Remaps the given labels to a new set of labels based on a subset of classes.

    Parameters:
    labels (array-like): The original labels to be remapped.
    class_subset (array-like): The subset of classes to which the labels should be remapped.

    Returns:
    numpy.ndarray: An array of remapped labels.
    """
    class_mapping = {original: new for new, original in enumerate(class_subset)}
    return np.array([class_mapping[label] for label in labels])

# %%
# Create subsets for train and test data
train_images_block_1, train_labels_block_1 = filter_by_classes(train_images, train_labels, block_1_classes)
train_images_block_2, train_labels_block_2 = filter_by_classes(train_images, train_labels, block_2_classes)
test_images_block_1, test_labels_block_1 = filter_by_classes(test_images, test_labels, block_1_classes)
test_images_block_2, test_labels_block_2 = filter_by_classes(test_images, test_labels, block_2_classes)

# print the shape of the train and test data
print(train_images_block_1.shape)
print(train_labels_block_1.shape)
print(train_images_block_2.shape)
print(train_labels_block_2.shape)
# Out:
# (25000, 32, 32, 3)
# (25000, 1)
# (25000, 32, 32, 3)
# (25000, 1)

# %%
train_labels_block_1 = remap_labels(train_labels_block_1.flatten().tolist(), block_1_classes)
test_labels_block_1 = remap_labels(test_labels_block_1.flatten().tolist(), block_1_classes)
train_labels_block_2 = remap_labels(train_labels_block_2.flatten().tolist(), block_2_classes)
test_labels_block_2 = remap_labels(test_labels_block_2.flatten().tolist(), block_2_classes)

# %% [markdown]
# #### Save the images for each block to disk for use in the next task.

# %%
def save_to_disk(data, labels, path):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    with open(path, 'wb') as f:
        pickle.dump((data, labels), f)

save_to_disk(train_images_block_1, train_labels_block_1, TRAIN_DIR_PATH+'/block_1_train.pkl')
save_to_disk(test_images_block_1, test_labels_block_1, TEST_DIR_PATH+'/block_1_test.pkl')

save_to_disk(train_images_block_2, train_labels_block_2, TRAIN_DIR_PATH+'/block_2_train.pkl')
save_to_disk(test_images_block_2, test_labels_block_2, TEST_DIR_PATH+'/block_2_test.pkl')

# %%
le = LabelEncoder()
train_labels_block_1 = le.fit_transform(train_labels_block_1)
test_labels_block_1 = le.transform(test_labels_block_1)

train_labels_block_1 = to_categorical(train_labels_block_1, num_classes=50)
test_labels_block_1 = to_categorical(test_labels_block_1, num_classes=50)

# %%
le_2 = LabelEncoder()
train_labels_block_2 = le_2.fit_transform(train_labels_block_2)
test_labels_block_2 = le_2.transform(test_labels_block_2)

train_labels_block_2 = to_categorical(train_labels_block_2, num_classes=50)
test_labels_block_2 = to_categorical(test_labels_block_2, num_classes=50)

# %%
print("Train data shape: ", train_images_block_1.shape)
print("Train labels shape: ", train_labels_block_1.shape)

print("Test data shape: ", test_images_block_1.shape)
print("Test labels shape: ", test_labels_block_1.shape)

print("Train data shape: ", train_images_block_2.shape)
print("Train labels shape: ", train_labels_block_2.shape)

print("Test data shape: ", test_images_block_2.shape)
print("Test labels shape: ", test_labels_block_2.shape)
# Out:
# Train data shape:  (25000, 32, 32, 3)
# Train labels shape:  (25000, 50)
# Test data shape:  (5000, 32, 32, 3)
# Test labels shape:  (5000, 50)
# Train data shape:  (25000, 32, 32, 3)
# Train labels shape:  (25000, 50)
# Test data shape:  (5000, 32, 32, 3)
# Test labels shape:  (5000, 50)

# %% [markdown]
# ### Basic Modelling: For Block 1 images:
# 1. Build a home-built network with 5 hidden layers of your choosing to classify the Block 1 images.
# 2. Report on relevant metrics and losses.
# 3. Investigate the use of different activation functions in this network.
# 4. Investigate the use of different losses in the network and the use of softmax vs logistic activation functions in the final layer.
# 5. Investigate the use of skip connections in network design.
# 6. Save the best performing model for the demo notebook and use later.

# %% [markdown]
# ### Constants

# %%
"""
This script sets up two Keras callbacks for training a deep learning model: EarlyStopping and ReduceLROnPlateau.

Callbacks:
    - EarlyStopping: Monitors the training process and stops training when a monitored metric has stopped improving.
        Parameters:
            min_delta (float): Minimum change in the monitored quantity to qualify as an improvement.
            patience (int): Number of epochs with no improvement after which training will be stopped.
            restore_best_weights (bool): Whether to restore model weights from the epoch with the best value of the monitored quantity.

    - ReduceLROnPlateau: Reduces the learning rate when a monitored metric has stopped improving.
        Parameters:
            monitor (str): Quantity to be monitored.
            factor (float): Factor by which the learning rate will be reduced. new_lr = lr * factor.
            patience (int): Number of epochs with no improvement after which learning rate will be reduced.
            min_lr (float): Lower bound on the learning rate.

The callbacks are stored in a list named `callbacks` and can be passed to the `fit` method of a Keras model.
"""

early_stopping = EarlyStopping(
    min_delta=0.001, # minimum amount of change to count as an improvement
    patience=15, # how many epochs to wait before stopping
    restore_best_weights=True,
)

reduceOnPlateau = ReduceLROnPlateau(
    monitor='val_loss', # value being monitored for improvement
    factor=0.1, # factor by which the learning rate will be reduced
    patience=5, # number of epochs with no improvement after which learning rate will be reduced
    min_lr=1e-6, # lower bound on the learning rate
)

callbacks = [early_stopping, reduceOnPlateau]

# %%
"""
Constants used to maintain consistency across initial training.

Attributes:
    OUTPUT_DIM (int): Dimensionality of the output space.
    BATCH_SIZE (int): Number of samples per gradient update.
    EPOCHS (int): Number of epochs to train the model.
    DROPOUT_RATE (float): Fraction of the input units to drop.
    DENSE_ACTIVATION (str): Activation function to use in dense layers.
    OPTIMIZER (str): Optimizer to use for training the model.
    VALIDATION_SPLIT (float): Fraction of the training data to be used as validation data.
"""
OUTPUT_DIM=50
BATCH_SIZE=32
EPOCHS=50
DROPOUT_RATE=0.5
DENSE_ACTIVATION='relu'
OPTIMIZER='adam'
VALIDATION_SPLIT=0.2

# %% [markdown]
# ### Utility Functions

# %%
# Plotting helper functions
def plot_training_results(history, metric='accuracy'):
    """
    Plots the training and validation results for a given metric over epochs.

    Parameters:
    history (dict): A dictionary containing the training history. It should have keys corresponding to the metric and 'val_' + metric.
    metric (str): The metric to plot (default is 'accuracy').

    Returns:
    None
    """
    plt.figure(figsize=(10, 6))
    plt.plot(history[metric], label='Training ' + metric)
    plt.plot(history['val_'+metric], label='Validation ' + metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.title('Training and Validation ' + metric)
    plt.legend()
    plt.show()

# %%
def evaluate_model(model, 
                   model_history, 
                   X_test,
                   y_test,
                   label_encoder=le):
    """
    Evaluates the performance of a trained model on the test dataset and 
    provides various performance metrics and visualizations.
    Parameters:
    model (keras.Model): The trained model to be evaluated.
    model_history (keras.callbacks.History): The history object returned by the model's fit method.
    X_test (numpy.ndarray): The test dataset features.
    y_test (numpy.ndarray): The test dataset labels.
    label_encoder (sklearn.preprocessing.LabelEncoder, optional): The label encoder used to transform the target variable. Default is 'le'.
    Returns:
    None
    Prints:
    - Test loss and accuracy.
    - Confusion matrix.
    - Accuracy score.
    - Classification report.
    Plots:
    - Training results for accuracy and loss.
    """
    loss, acc = model.evaluate(X_test, y_test)
    print('Test loss: ', loss)
    print('Test accuracy: ', acc)

  
    y_pred = model.predict(X_test)
    y_pred = np.argmax(y_pred, axis=1)
    y_true = np.argmax(y_test, axis=1)
    print('Confusion matrix:')
    print(confusion_matrix(y_true, y_pred))

    # make predictions
    y_pred = model.predict(X_test)

    # convert the predictions to the target variable
    y_pred = label_encoder.inverse_transform(y_pred.argmax(axis=1))

    # convert the test target variable to the original values
    y_test = label_encoder.inverse_transform(y_test.argmax(axis=1))

    print(accuracy_score(y_test, y_pred))
        
    # Print classification report
    print(classification_report(y_test, y_pred))
    
    # Plot results
    plot_training_results(model_history)
    plot_training_results(model_history, metric='loss')

# %% [markdown]
# #### Basic Model (Version 1)

# %%
# from tensorflow.keras.layers import Input, Dense, Flatten, Rescaling
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import add

# def create_model(output_dim=50,
#                 activation='relu',
#                 optimizer='adam',
#                 final_activation='softmax',
#                 loss_function='categorical_crossentropy',
#                 use_skip=False):
#     inputs = Input(shape=(32, 32, 3))
#     input_layer = Flatten()(inputs)
    
#     # First hidden layer
#     dense_one = Dense(512, activation=activation)(input_layer)
#     # Second hidden layer
#     dense_two = Dense(256, activation=activation)(dense_one)
    
#     # Optional skip connection
#     if use_skip:
#         # Match the dimensions before adding
#         dense_one_resized = Dense(256, activation=activation)(dense_one)
#         dense_two = add([dense_one_resized, dense_two])

#     # Third hidden layer
#     dense_three = Dense(128, activation=activation)(dense_two)
#     # Fourth hidden layer
#     dense_four = Dense(64, activation=activation)(dense_three)
#     # Fifth hidden layer
#     dense_five = Dense(32, activation=activation)(dense_four)
#     # Output layer
#     outputs = Dense(output_dim, activation=final_activation)(dense_five)

#     model = Model(inputs, outputs)

#     # Compile the model
#     model.compile(optimizer=optimizer,
#                 loss=loss_function,
#                 metrics=['accuracy'])
#     return model

# %% [markdown]
# ### Basic Modelling: For Block 1 images:
# 1. Build a home-built network with 5 hidden layers of your choosing to classify the Block 1 images.

# %% [markdown]
# #### Advanced Model (Version 2)

# %%
def create_model(output_dim=50,
                 activation='relu',
                 optimizer='adam',
                 final_activation='softmax',
                 loss_function='categorical_crossentropy',
                 use_skip=False):
    """
    Creates and compiles a Convolutional Neural Network (CNN) model.
    Parameters:
    output_dim (int): The dimension of the output layer. Default is 50.
    activation (str): The activation function to use in the convolutional and dense layers. Default is 'relu'.
    optimizer (str): The optimizer to use for compiling the model. Default is 'adam'.
    final_activation (str): The activation function to use in the output layer. Default is 'softmax'.
    loss_function (str): The loss function to use for compiling the model. Default is 'categorical_crossentropy'.
    use_skip (bool): Whether to use skip connections in the dense layers. Default is False.
    Returns:
    model (tf.keras.Model): The compiled CNN model.
    """
    inputs = Input(shape=(32, 32, 3))

    # Encoder layers
    conv1 = Conv2D(32, (3, 3), activation=activation, padding='same')(inputs)
    pool1 = MaxPooling2D((2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation=activation, padding='same')(pool1)
    pool2 = MaxPooling2D((2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation=activation, padding='same')(pool2)
    pool3 = MaxPooling2D((2, 2))(conv3)

    # Flatten layer
    flat = Flatten()(pool3)

    # Dense layers for encoding
    dense_one = Dense(64, activation=activation)(flat)
    dense_two = Dense(128, activation=activation)(dense_one)

    if use_skip:
        dense_one_resized = Dense(128, activation=activation)(dense_one)
        dense_two = add([dense_one_resized, dense_two])

    dense_three = Dense(256, activation=activation)(dense_two)

    # Output layer
    final_output = Dense(output_dim, activation=final_activation)(dense_three)

    model = Model(inputs, final_output)

    model.compile(optimizer=optimizer,
                  loss=loss_function,
                  metrics=['accuracy'])

    return model

# %%
# create the basic model
basic_model = create_model()
basic_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  dense_3 (Dense)             (None, 50)                12850
#
# =================================================================
# Total params: 278578 (1.06 MB)
# Trainable params: 278578 (1.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Check the shapes of train_data_block_1 and train_labels_block_1
print("Shape of train_data_block_1:", train_images_block_1.shape)
print("Shape of train_labels_block_1:", train_labels_block_1.shape)

# train the model
model_history = basic_model.fit(train_images_block_1, train_labels_block_1, 
                                batch_size=BATCH_SIZE, 
                                epochs=EPOCHS, 
                                validation_split=VALIDATION_SPLIT, 
                                callbacks=callbacks)
# Out:
# Shape of train_data_block_1: (25000, 32, 32, 3)
# Shape of train_labels_block_1: (25000, 50)
# Epoch 1/50
# 625/625 [==============================] - 9s 14ms/step - loss: 3.4605 - accuracy: 0.0860 - val_loss: 3.1773 - val_accuracy: 0.1378 - lr: 0.0010
# Epoch 2/50
# 625/625 [==============================] - 9s 14ms/step - loss: 2.9729 - accuracy: 0.1867 - val_loss: 2.8203 - val_accuracy: 0.2232 - lr: 0.0010
# Epoch 3/50
# 625/625 [==============================] - 9s 14ms/step - loss: 2.6502 - accuracy: 0.2610 - val_loss: 2.6016 - val_accuracy: 0.2714 - lr: 0.0010
# Epoch 4/50
# 625/625 [==============================] - 9s 14ms/step - loss: 2.4366 - accuracy: 0.3159 - val_loss: 2.4531 - val_accuracy: 0.3188 - lr: 0.0010
# Epoch 5/50
# 625/625 [==============================] - 9s 15ms/step - loss: 2.2503 - accuracy: 0.3582 - val_loss: 2.3968 - val_accuracy: 0.3406 - lr: 0.0010
# Epoch 6/50
# 625/625 [==============================] - 10s 16ms/step - loss: 2.0859 - accuracy: 0.3972 - val_loss: 2.4393 - val_accuracy: 0.3362 - lr: 0.0010
# Epoch 7/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.9367 - accuracy: 0.4368 - val_loss: 2.3893 - val_accuracy: 0.3506 - lr: 0.0010
# Epoch 8/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.7821 - accuracy: 0.4759 - val_loss: 2.3549 - val_accuracy: 0.3648 - lr: 0.0010
# Epoch 9/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.6408 - accuracy: 0.5138 - val_loss: 2.3826 - val_accuracy: 0.3612 - lr: 0.0010
# Epoch 10/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.5016 - accuracy: 0.5483 - val_loss: 2.4432 - val_accuracy: 0.3780 - lr: 0.0010
# Epoch 11/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.3745 - accuracy: 0.5836 - val_loss: 2.4888 - val_accuracy: 0.3780 - lr: 0.0010
# Epoch 12/50
# 625/625 [==============================] - 10s 17ms/step - loss: 1.2463 - accuracy: 0.6201 - val_loss: 2.6199 - val_accuracy: 0.3842 - lr: 0.0010
# Epoch 13/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.1338 - accuracy: 0.6491 - val_loss: 2.6753 - val_accuracy: 0.3864 - lr: 0.0010
# Epoch 14/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.7422 - accuracy: 0.7744 - val_loss: 2.7363 - val_accuracy: 0.4140 - lr: 1.0000e-04
# Epoch 15/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.6513 - accuracy: 0.8019 - val_loss: 2.8554 - val_accuracy: 0.4112 - lr: 1.0000e-04
# Epoch 16/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.6049 - accuracy: 0.8182 - val_loss: 2.9702 - val_accuracy: 0.4096 - lr: 1.0000e-04
# Epoch 17/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.5685 - accuracy: 0.8310 - val_loss: 3.0406 - val_accuracy: 0.4116 - lr: 1.0000e-04
# Epoch 18/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.5339 - accuracy: 0.8417 - val_loss: 3.1194 - val_accuracy: 0.4100 - lr: 1.0000e-04
# Epoch 19/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.4807 - accuracy: 0.8622 - val_loss: 3.1435 - val_accuracy: 0.4124 - lr: 1.0000e-05
# Epoch 20/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.4728 - accuracy: 0.8647 - val_loss: 3.1702 - val_accuracy: 0.4118 - lr: 1.0000e-05
# Epoch 21/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.4685 - accuracy: 0.8670 - val_loss: 3.1848 - val_accuracy: 0.4110 - lr: 1.0000e-05
# Epoch 22/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.4648 - accuracy: 0.8683 - val_loss: 3.1978 - val_accuracy: 0.4104 - lr: 1.0000e-05
# Epoch 23/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.4609 - accuracy: 0.8698 - val_loss: 3.2188 - val_accuracy: 0.4100 - lr: 1.0000e-05

# %% [markdown]
# #### 2. Report on relevant metrics and losses.

# %%
# evaluate the model
evaluate_model(basic_model, model_history.history, test_images_block_1, test_labels_block_1)
# Out:
# 157/157 [==============================] - 1s 7ms/step - loss: 2.3504 - accuracy: 0.3628
# Test loss:  2.3504233360290527
# Test accuracy:  0.3628000020980835
# 157/157 [==============================] - 1s 7ms/step
# Confusion matrix:
# [[28 19 10 ...  0  7  0]
#  [ 2 73  4 ...  0  4  0]
#  [ 1  2 61 ...  0 13  2]
#  ...
#  [ 1  3  3 ... 11  0  2]
#  [ 6 12 18 ...  0 46  0]
#  [ 0  2  0 ...  0  1 35]]
# 157/157 [==============================] - 1s 6ms/step
# 0.3628
#               precision    recall  f1-score   support
#
#            0       0.41      0.28      0.33       100
#            1       0.47      0.73      0.57       100
#            2       0.44      0.61      0.51       100
#            3       0.21      0.15      0.17       100
#            4       0.15      0.18      0.16       100
#            5       0.61      0.35      0.45       100
#            6       0.45      0.23      0.30       100
#            7       0.23      0.08      0.12       100
#            8       0.35      0.17      0.23       100
#            9       0.61      0.54      0.57       100
#           10       0.34      0.57      0.42       100
#           11       0.33      0.55      0.41       100
#           12       0.38      0.30      0.34       100
#           13       0.38      0.44      0.41       100
#           14       0.31      0.31      0.31       100
#           15       0.17      0.09      0.12       100
#           16       0.71      0.54      0.61       100
#           17       0.16      0.30      0.21       100
#           18       0.29      0.44      0.35       100
#           19       0.39      0.42      0.40       100
#           20       0.13      0.24      0.16       100
#           21       0.39      0.14      0.21       100
#           22       0.38      0.33      0.35       100
#           23       0.32      0.38      0.35       100
#           24       0.38      0.71      0.50       100
#           25       0.29      0.32      0.30       100
#           26       0.46      0.23      0.31       100
#           27       0.54      0.35      0.42       100
#           28       0.51      0.46      0.48       100
#           29       0.23      0.07      0.11       100
#           30       0.42      0.34      0.38       100
#           31       0.67      0.56      0.61       100
#           32       0.63      0.46      0.53       100
#           33       0.47      0.55      0.51       100
#           34       0.31      0.22      0.26       100
#           35       0.29      0.35      0.32       100
#           36       0.35      0.43      0.38       100
#           37       0.26      0.18      0.21       100
#           38       0.41      0.32      0.36       100
#           39       0.45      0.38      0.41       100
#           40       0.59      0.54      0.57       100
#           41       0.21      0.60      0.32       100
#           42       0.65      0.33      0.44       100
#           43       0.58      0.30      0.39       100
#           44       0.19      0.43      0.27       100
#           45       0.53      0.40      0.46       100
#           46       0.33      0.32      0.33       100
#           47       0.37      0.11      0.17       100
#           48       0.52      0.46      0.49       100
#           49       0.34      0.35      0.34       100
#
#     accuracy                           0.36      5000
#    macro avg       0.39      0.36      0.36      5000
# weighted avg       0.39      0.36      0.36      5000

# %% [markdown]
# #### 3. Investigate the use of different activation functions in this network.

# %%
# create a definition to loop through the different models
def run_activation_experiment(activations, 
                              model, 
                              train_images, 
                              train_labels, 
                              test_images, 
                              test_labels, 
                              callbacks):

    # create a list to hold investigation results
    results = []
    # loop through the activation functions
    for activation in activations:
        print(f'Running experiment with activation: {activation}')
        # create the model
        model = create_model(activation=activation)
        # train the model
        model_history = model.fit(train_images, train_labels, 
                                    batch_size=BATCH_SIZE, 
                                    epochs=EPOCHS, 
                                    validation_split=VALIDATION_SPLIT, 
                                    callbacks=callbacks)

        # evaluate the model
        loss, accuracy = model.evaluate(test_images, test_labels)
        results.append({
            'experiment': 'activation',
            'model': model,
            'history': model_history.history,
            'experiment_variable': activation,
            'loss': loss,
            'accuracy': accuracy
        })
    results = sorted(results, key=lambda x: x['accuracy'], reverse=True)
    return results

# %%
# create a list of activation functions
activations = ['relu','leaky_relu','tanh','sigmoid','softmax']

activation_results = run_activation_experiment(activations,
                                                basic_model,
                                                train_images_block_1,
                                                train_labels_block_1,
                                                test_images_block_1,
                                                test_labels_block_1,
                                                callbacks)

# print the top result
print(activation_results[0])
# Out:
# Running experiment with activation: relu
# Epoch 1/50
# 625/625 [==============================] - 11s 17ms/step - loss: 3.5016 - accuracy: 0.0783 - val_loss: 3.2058 - val_accuracy: 0.1356 - lr: 0.0010
# Epoch 2/50
# 625/625 [==============================] - 10s 17ms/step - loss: 3.0187 - accuracy: 0.1723 - val_loss: 2.9430 - val_accuracy: 0.1946 - lr: 0.0010
# Epoch 3/50
# 625/625 [==============================] - 11s 17ms/step - loss: 2.7500 - accuracy: 0.2328 - val_loss: 2.6894 - val_accuracy: 0.2542 - lr: 0.0010
# Epoch 4/50
# 625/625 [==============================] - 11s 17ms/step - loss: 2.5252 - accuracy: 0.2887 - val_loss: 2.5774 - val_accuracy: 0.2806 - lr: 0.0010
# Epoch 5/50
# 625/625 [==============================] - 11s 17ms/step - loss: 2.3413 - accuracy: 0.3339 - val_loss: 2.4210 - val_accuracy: 0.3282 - lr: 0.0010
# Epoch 6/50
# 625/625 [==============================] - 11s 17ms/step - loss: 2.1851 - accuracy: 0.3711 - val_loss: 2.3814 - val_accuracy: 0.3428 - lr: 0.0010
# Epoch 7/50
# 625/625 [==============================] - 11s 17ms/step - loss: 2.0301 - accuracy: 0.4098 - val_loss: 2.3747 - val_accuracy: 0.3568 - lr: 0.0010
# Epoch 8/50
# 625/625 [==============================] - 11s 17ms/step - loss: 1.9036 - accuracy: 0.4451 - val_loss: 2.4155 - val_accuracy: 0.3508 - lr: 0.0010
# Epoch 9/50
# 625/625 [==============================] - 11s 17ms/step - loss: 1.7849 - accuracy: 0.4732 - val_loss: 2.3080 - val_accuracy: 0.3808 - lr: 0.0010
# Epoch 10/50
# 625/625 [==============================] - 11s 17ms/step - loss: 1.6533 - accuracy: 0.5097 - val_loss: 2.3348 - val_accuracy: 0.3782 - lr: 0.0010
# Epoch 11/50
# 625/625 [==============================] - 11s 18ms/step - loss: 1.5350 - accuracy: 0.5371 - val_loss: 2.4219 - val_accuracy: 0.3758 - lr: 0.0010
# Epoch 12/50
# 625/625 [==============================] - 11s 18ms/step - loss: 1.4327 - accuracy: 0.5606 - val_loss: 2.4494 - val_accuracy: 0.3704 - lr: 0.0010
# Epoch 13/50
# 625/625 [==============================] - 11s 17ms/step - loss: 1.3234 - accuracy: 0.5994 - val_loss: 2.6210 - val_accuracy: 0.3712 - lr: 0.0010
# Epoch 14/50
# 625/625 [==============================] - 11s 17ms/step - loss: 1
- val_loss: 3.9146 - val_accuracy: 0.0170 - lr: 1.0000e-05
# 157/157 [==============================] - 1s 9ms/step - loss: 3.9122 - accuracy: 0.0200
# {'experiment': 'activation', 'model': <keras.src.engine.functional.Functional object at 0x3d73257d0>, 'history': {'loss': [3.2717068195343018, 2.6420061588287354, 2.2781975269317627, 1.9952648878097534, 1.7652487754821777, 1.5504543781280518, 1.3535330295562744, 1.1557791233062744, 0.9933373332023621, 0.838000476360321, 0.7067673206329346, 0.3510988652706146, 0.25722095370292664, 0.21224135160446167, 0.17739541828632355, 0.14768101274967194, 0.11318907141685486, 0.1083131805062294, 0.10509288311004639, 0.10198047012090683, 0.0989995151758194], 'accuracy': [0.13210000097751617, 0.2662000060081482, 0.3531999886035919, 0.4239000082015991, 0.48295000195503235, 0.5372999906539917, 0.5921000242233276, 0.6431499719619751, 0.6898000240325928, 0.7317000031471252, 0.7736999988555908, 0.896049976348877, 0.9273499846458435, 0.9415000081062317, 0.9538999795913696, 0.9641500115394592, 0.9768499732017517, 0.9781000018119812, 0.9792500138282776, 0.9795500040054321, 0.980650007724762], 'val_loss': [2.9152674674987793, 2.511021375656128, 2.2994446754455566, 2.174760103225708, 2.1465418338775635, 2.1253483295440674, 2.1662256717681885, 2.244093894958496, 2.349808931350708, 2.4979422092437744, 2.873720169067383, 2.751997947692871, 2.9203083515167236, 3.09507155418396, 3.2730798721313477, 3.4721837043762207, 3.507957696914673, 3.5336081981658936, 3.5704123973846436, 3.6127429008483887, 3.6345198154449463], 'val_accuracy': [0.20800000429153442, 0.3046000003814697, 0.35899999737739563, 0.3898000121116638, 0.40639999508857727, 0.43320000171661377, 0.42879998683929443, 0.4390000104904175, 0.4456000030040741, 0.4397999942302704, 0.430400013923645, 0.45579999685287476, 0.453000009059906, 0.45159998536109924, 0.4528000056743622, 0.44839999079704285, 0.4498000144958496, 0.44920000433921814, 0.44839999079704285, 0.4480000138282776, 0.44920000433921814], 'lr': [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.000100000005, 0.000100000005, 0.000100000005, 0.000100000005, 0.000100000005, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05]}, 'experiment_variable': 'leaky_relu', 'loss': 2.0989465713500977, 'accuracy': 0.4302000105381012}

# %%
# select the best model
best_activation_model = activation_results[0]['model']
best_activation_model_history = activation_results[0]['history']

# set a variable to hold the best activation method
best_activation_method = activation_results[0]['experiment_variable']

# print the best activation method
print(f'Best activation method: {best_activation_method}')
# Out:
# Best activation method: leaky_relu

# %%
# evaluate the best model
evaluate_model(best_activation_model, best_activation_model_history, test_images_block_1, test_labels_block_1)
# Out:
# 157/157 [==============================] - 1s 7ms/step - loss: 2.0989 - accuracy: 0.4302
# Test loss:  2.0989465713500977
# Test accuracy:  0.4302000105381012
# 157/157 [==============================] - 1s 7ms/step
# Confusion matrix:
# [[45 14  3 ...  1  7  3]
#  [ 3 75  0 ...  0  6  2]
#  [ 5  0 55 ...  1 11  2]
#  ...
#  [ 1  1  0 ... 34  2  2]
#  [ 6  7  9 ...  1 61  3]
#  [ 2  1  0 ...  0  1 55]]
# 157/157 [==============================] - 1s 7ms/step
# 0.4302
#               precision    recall  f1-score   support
#
#            0       0.43      0.45      0.44       100
#            1       0.66      0.75      0.70       100
#            2       0.63      0.55      0.59       100
#            3       0.31      0.22      0.26       100
#            4       0.35      0.14      0.20       100
#            5       0.46      0.51      0.49       100
#            6       0.49      0.41      0.45       100
#            7       0.32      0.18      0.23       100
#            8       0.32      0.40      0.35       100
#            9       0.75      0.64      0.69       100
#           10       0.37      0.48      0.42       100
#           11       0.30      0.61      0.40       100
#           12       0.42      0.49      0.45       100
#           13       0.37      0.59      0.45       100
#           14       0.25      0.29      0.27       100
#           15       0.37      0.27      0.31       100
#           16       0.84      0.65      0.73       100
#           17       0.31      0.24      0.27       100
#           18       0.40      0.52      0.45       100
#           19       0.51      0.39      0.44       100
#           20       0.23      0.16      0.19       100
#           21       0.31      0.48      0.37       100
#           22       0.45      0.41      0.43       100
#           23       0.37      0.52      0.44       100
#           24       0.57      0.65      0.60       100
#           25       0.44      0.24      0.31       100
#           26       0.39      0.41      0.40       100
#           27       0.48      0.27      0.35       100
#           28       0.59      0.46      0.52       100
#           29       0.21      0.11      0.14       100
#           30       0.47      0.33      0.39       100
#           31       0.54      0.76      0.63       100
#           32       0.52      0.66      0.58       100
#           33       0.69      0.49      0.57       100
#           34       0.39      0.22      0.28       100
#           35       0.51      0.39      0.44       100
#           36       0.35      0.55      0.42       100
#           37       0.38      0.35      0.36       100
#           38       0.40      0.34      0.37       100
#           39       0.41      0.52      0.46       100
#           40       0.71      0.45      0.55       100
#           41       0.43      0.35      0.39       100
#           42       0.66      0.47      0.55       100
#           43       0.47      0.34      0.39       100
#           44       0.30      0.42      0.35       100
#           45       0.44      0.34      0.38       100
#           46       0.35      0.54      0.43       100
#           47       0.38      0.34      0.36       100
#           48       0.60      0.61      0.61       100
#           49       0.30      0.55      0.39       100
#
#     accuracy                           0.43      5000
#    macro avg       0.44      0.43      0.42      5000
# weighted avg       0.44      0.43      0.42      5000

# %% [markdown]
# #### 5. Investigate the use of different losses in the network and the use of softmax vs logistic activation functions in the final layer.

# %% [markdown]
# ##### 5a. Investigate different loss functions

# %%
def run_loss_function_experiment(loss_functions, 
                                model, 
                                train_images, 
                                train_labels, 
                                test_images, 
                                test_labels, 
                                callbacks):
    """
    Runs an experiment to evaluate the performance of a model with different loss functions.

    Parameters:
    loss_functions (list): A list of loss functions to evaluate.
    model (tf.keras.Model): The model to train and evaluate.
    train_images (numpy.ndarray): The training data features.
    train_labels (numpy.ndarray): The training data labels.
    test_images (numpy.ndarray): The test data features.
    test_labels (numpy.ndarray): The test data labels.
    callbacks (list): A list of Keras callbacks to use during training.

    Returns:
    list: A list of dictionaries containing the results of the experiments
    """
    results = []
    for loss_function in loss_functions:
        print(f'Running experiment with loss function: {loss_function}')
        model = create_model(loss_function=loss_function)
        model_history = model.fit(train_images, train_labels, 
                                  batch_size=BATCH_SIZE, 
                                  epochs=EPOCHS, 
                                  validation_split=VALIDATION_SPLIT, 
                                  callbacks=callbacks)
        loss, accuracy = model.evaluate(test_images, test_labels)
        results.append({
            'experiment': 'loss_function',
            'model': model,
            'history': model_history.history,
            'experiment_variable': loss_function,
            'loss': loss,
            'accuracy': accuracy
        })
    results = sorted(results, key=lambda x: x['accuracy'], reverse=True)
    return results

# %%
# loss functions suitable for multi-class classification
loss_functions = [KLDivergence(),'categorical_crossentropy']

# run the loss function experiment
loss_function_results = run_loss_function_experiment(loss_functions,
                                                    basic_model,
                                                    train_images_block_1,
                                                    train_labels_block_1,
                                                    test_images_block_1,
                                                    test_labels_block_1,
                                                    callbacks)

# print the top result
print(loss_function_results[0])
# Out:
# Running experiment with loss function: <keras.src.losses.KLDivergence object at 0x15e53d5d0>
# Epoch 1/50
# 625/625 [==============================] - 11s 17ms/step - loss: 3.4738 - accuracy: 0.0822 - val_loss: 3.2543 - val_accuracy: 0.1308 - lr: 0.0010
# Epoch 2/50
# 625/625 [==============================] - 11s 17ms/step - loss: 3.0573 - accuracy: 0.1672 - val_loss: 2.9125 - val_accuracy: 0.2124 - lr: 0.0010
# Epoch 3/50
# 625/625 [==============================] - 11s 17ms/step - loss: 2.7977 - accuracy: 0.2295 - val_loss: 2.7353 - val_accuracy: 0.2532 - lr: 0.0010
# Epoch 4/50
# 625/625 [==============================] - 11s 17ms/step - loss: 2.5800 - accuracy: 0.2768 - val_loss: 2.5773 - val_accuracy: 0.2808 - lr: 0.0010
# Epoch 5/50
# 625/625 [==============================] - 11s 17ms/step - loss: 2.3935 - accuracy: 0.3216 - val_loss: 2.5783 - val_accuracy: 0.2908 - lr: 0.0010
# Epoch 6/50
# 625/625 [==============================] - 11s 18ms/step - loss: 2.2220 - accuracy: 0.3661 - val_loss: 2.4615 - val_accuracy: 0.3190 - lr: 0.0010
# Epoch 7/50
# 625/625 [==============================] - 11s 18ms/step - loss: 2.0826 - accuracy: 0.3993 - val_loss: 2.3379 - val_accuracy: 0.3630 - lr: 0.0010
# Epoch 8/50
# 625/625 [==============================] - 11s 17ms/step - loss: 1.9453 - accuracy: 0.4338 - val_loss: 2.3057 - val_accuracy: 0.3684 - lr: 0.0010
# Epoch 9/50
# 625/625 [==============================] - 11s 17ms/step - loss: 1.8186 - accuracy: 0.4685 - val_loss: 2.3048 - val_accuracy: 0.3798 - lr: 0.0010
# Epoch 10/50
# 625/625 [==============================] - 11s 18ms/step - loss: 1.7115 - accuracy: 0.4888 - val_loss: 2.3949 - val_accuracy: 0.3790 - lr: 0.0010
# Epoch 11/50
# 625/625 [==============================] - 11s 18ms/step - loss: 1.5868 - accuracy: 0.5275 - val_loss: 2.3870 - val_accuracy: 0.3740 - lr: 0.0010
# Epoch 12/50
# 625/625 [==============================] - 11s 18ms/step - loss: 1.4869 - accuracy: 0.5492 - val_loss: 2.5012 - val_accuracy: 0.3710 - lr: 0.0010
# Epoch 13/50
# 625/625 [==============================] - 11s 18ms/step - loss: 1.3886 - accuracy: 0.5785 - val_loss: 2.4920 - val_accuracy: 0.3830 - lr: 0.0010
# Epoch 14/50
# 625/625 [==============================] - 11s 18ms/step - loss: 1.2848 - accuracy: 0.6028 - val_loss: 2.5699 - val_accuracy: 0.3770 - lr: 0.0010
# Epoch 15/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.9294 - accuracy: 0.7157 - val_loss: 2.5914 - val_accuracy: 0.4082 - lr: 1.0000e-04
# Epoch 16/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.8419 - accuracy: 0.7441 - val_loss: 2.6554 - val_accuracy: 0.4044 - lr: 1.0000e-04
# Epoch 17/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.8000 - accuracy: 0.7588 - val_loss: 2.7065 - val_accuracy: 0.4102 - lr: 1.0000e-04
# Epoch 18/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.7673 - accuracy: 0.7689 - val_loss: 2.7711 - val_accuracy: 0.4072 - lr: 1.0000e-04
# Epoch 19/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.7386 - accuracy: 0.7778 - val_loss: 2.8156 - val_accuracy: 0.4058 - lr: 1.0000e-04
# Epoch 20/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.6823 - accuracy: 0.8007 - val_loss: 2.8196 - val_accuracy: 0.4098 - lr: 1.0000e-05
# Epoch 21/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.6763 - accuracy: 0.8025 - val_loss: 2.8340 - val_accuracy: 0.4090 - lr: 1.0000e-05
# Epoch 22/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.6723 - accuracy: 0.8037 - val_loss: 2.8504 - val_accuracy: 0.4102 - lr: 1.0000e-05
# Epoch 23/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.6692 - accuracy: 0.8037 - val_loss: 2.8602 - val_accuracy: 0.4096 - lr: 1.0000e-05
# 157/157 [==============================] - 1s 7ms/step - loss: 2.2760 - accuracy: 0.3694
# Running experiment with loss function: categorical_crossentropy
# Epoch 1/50
# 625/625 [==============================] - 11s 18ms/step - loss: 3.4806 - accuracy: 0.0802 - val_loss: 3.1815 - val_accuracy: 0.1288 - lr: 0.0010
# Epoch 2/50
# 625/625 [==============================] -
- lr: 1.0000e-05
# 157/157 [==============================] - 1s 6ms/step - loss: 2.3138 - accuracy: 0.3814
# {'experiment': 'loss_function', 'model': <keras.src.engine.functional.Functional object at 0x15e866f10>, 'history': {'loss': [3.4805569648742676, 3.017637014389038, 2.739820718765259, 2.5227394104003906, 2.333880662918091, 2.171154022216797, 2.0195472240448, 1.878437876701355, 1.742295265197754, 1.6240038871765137, 1.5009217262268066, 1.3917707204818726, 1.2759040594100952, 1.1763802766799927, 1.0839585065841675, 0.7307696342468262, 0.6354436874389648, 0.5899032950401306, 0.5540245175361633, 0.5208770632743835, 0.4676918387413025, 0.46141499280929565, 0.45734378695487976, 0.45371654629707336, 0.4503563940525055], 'accuracy': [0.08020000159740448, 0.17065000534057617, 0.2312999963760376, 0.288349986076355, 0.3358500003814697, 0.37310001254081726, 0.4161500036716461, 0.446150004863739, 0.4809499979019165, 0.5097500085830688, 0.541700005531311, 0.574400007724762, 0.6025500297546387, 0.6323500275611877, 0.6585500240325928, 0.7743499875068665, 0.8041999936103821, 0.8187500238418579, 0.8314999938011169, 0.8425499796867371, 0.8650000095367432, 0.8675500154495239, 0.8691499829292297, 0.8692499995231628, 0.871749997138977], 'val_loss': [3.181546926498413, 2.868561029434204, 2.725553512573242, 2.541560173034668, 2.4841480255126953, 2.4469406604766846, 2.3945910930633545, 2.4142234325408936, 2.4450392723083496, 2.3635306358337402, 2.391902446746826, 2.485088348388672, 2.555967330932617, 2.6669187545776367, 2.9990673065185547, 2.911165475845337, 3.0758368968963623, 3.1828911304473877, 3.275775671005249, 3.3744053840637207, 3.4087202548980713, 3.430995225906372, 3.446890115737915, 3.4648895263671875, 3.4819157123565674], 'val_accuracy': [0.12880000472068787, 0.21040000021457672, 0.24779999256134033, 0.2924000024795532, 0.30660000443458557, 0.3319999873638153, 0.3375999927520752, 0.34380000829696655, 0.35199999809265137, 0.38119998574256897, 0.36980000138282776, 0.37619999051094055, 0.3734000027179718, 0.37220001220703125, 0.3449999988079071, 0.39259999990463257, 0.39500001072883606, 0.3921999931335449, 0.3905999958515167, 0.3889999985694885, 0.3880000114440918, 0.38679999113082886, 0.3898000121116638, 0.3898000121116638, 0.38920000195503235], 'lr': [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.000100000005, 0.000100000005, 0.000100000005, 0.000100000005, 0.000100000005, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05]}, 'experiment_variable': 'categorical_crossentropy', 'loss': 2.313828945159912, 'accuracy': 0.3813999891281128}

# %%
# select the best model
best_loss_function_model = loss_function_results[0]['model']

# set a variable to hold the best loss function
best_loss_function = loss_function_results[0]['experiment_variable']

# print the best loss function
print(f'Best loss function: {best_loss_function}')

# evaluate the best model
evaluate_model(best_loss_function_model, loss_function_results[0]['history'], test_images_block_1, test_labels_block_1)
# Out:
# Best loss function: categorical_crossentropy
# 157/157 [==============================] - 1s 7ms/step - loss: 2.3138 - accuracy: 0.3814
# Test loss:  2.313828945159912
# Test accuracy:  0.3813999891281128
# 157/157 [==============================] - 1s 7ms/step
# Confusion matrix:
# [[42 13 12 ...  0  4  1]
#  [ 5 70  0 ...  1  3  2]
#  [ 7  1 60 ...  2  6  2]
#  ...
#  [ 5  1  1 ... 22  0  1]
#  [15  6 18 ...  0 45  1]
#  [ 1  1  0 ...  1  0 27]]
# 157/157 [==============================] - 1s 7ms/step
# 0.3814
#               precision    recall  f1-score   support
#
#            0       0.39      0.42      0.41       100
#            1       0.63      0.70      0.66       100
#            2       0.48      0.60      0.53       100
#            3       0.27      0.23      0.25       100
#            4       0.29      0.16      0.21       100
#            5       0.44      0.49      0.46       100
#            6       0.31      0.42      0.36       100
#            7       0.17      0.25      0.20       100
#            8       0.35      0.24      0.29       100
#            9       0.66      0.64      0.65       100
#           10       0.35      0.35      0.35       100
#           11       0.30      0.63      0.41       100
#           12       0.51      0.37      0.43       100
#           13       0.36      0.40      0.38       100
#           14       0.33      0.20      0.25       100
#           15       0.23      0.27      0.25       100
#           16       0.54      0.72      0.62       100
#           17       0.16      0.07      0.10       100
#           18       0.39      0.43      0.41       100
#           19       0.32      0.51      0.39       100
#           20       0.15      0.09      0.11       100
#           21       0.38      0.25      0.30       100
#           22       0.36      0.22      0.27       100
#           23       0.24      0.55      0.33       100
#           24       0.48      0.58      0.52       100
#           25       0.45      0.25      0.32       100
#           26       0.35      0.23      0.28       100
#           27       0.43      0.53      0.48       100
#           28       0.59      0.44      0.50       100
#           29       0.27      0.15      0.19       100
#           30       0.35      0.31      0.33       100
#           31       0.68      0.44      0.53       100
#           32       0.53      0.59      0.56       100
#           33       0.54      0.55      0.55       100
#           34       0.21      0.24      0.22       100
#           35       0.45      0.36      0.40       100
#           36       0.24      0.50      0.33       100
#           37       0.25      0.27      0.26       100
#           38       0.40      0.25      0.31       100
#           39       0.47      0.42      0.44       100
#           40       0.67      0.51      0.58       100
#           41       0.33      0.41      0.37       100
#           42       0.58      0.36      0.44       100
#           43       0.55      0.36      0.44       100
#           44       0.37      0.19      0.25       100
#           45       0.49      0.40      0.44       100
#           46       0.27      0.58      0.37       100
#           47       0.27      0.22      0.24       100
#           48       0.60      0.45      0.51       100
#           49       0.35      0.27      0.31       100
#
#     accuracy                           0.38      5000
#    macro avg       0.40      0.38      0.38      5000
# weighted avg       0.40      0.38      0.38      5000

# %% [markdown]
# ##### 5b. Investigate different final activation

# %%
# create a function to loop over different final activation functions
def run_final_activation_experiment(final_activations, 
                                    model, 
                                    train_images, 
                                    train_labels, 
                                    test_images, 
                                    test_labels, 
                                    callbacks):

    # create a list to hold investigation results
    results = []
    # loop through the activation functions
    for activation in final_activations:
        print(f'Running experiment with final activation: {activation}')
        # create the model
        model = create_model(final_activation=activation)
        # train the model
        model_history = model.fit(train_images, train_labels, 
                                    batch_size=BATCH_SIZE, 
                                    epochs=EPOCHS, 
                                    validation_split=VALIDATION_SPLIT, 
                                    callbacks=callbacks)

        # evaluate the model
        loss, accuracy = model.evaluate(test_images, test_labels)
        results.append({
            'experiment': 'final_activation',
            'model': model,
            'history': model_history.history,
            'experiment_variable': activation,
            'loss': loss,
            'accuracy': accuracy
        })
    results = sorted(results, key=lambda x: x['accuracy'], reverse=True)
    return results

# %%
# create a list of final activation functions
final_activations = ['softmax', 'sigmoid', 'tanh', 'relu', 'elu', 'linear']

final_activation_results = run_final_activation_experiment(final_activations,
                                                            best_activation_model,
                                                            train_images_block_1,
                                                            train_labels_block_1,
                                                            test_images_block_1,
                                                            test_labels_block_1,
                                                            callbacks)

# print the top result
print(final_activation_results[0])
# Out:
# Running experiment with final activation: softmax
# Epoch 1/50
# 625/625 [==============================] - 12s 18ms/step - loss: 3.4595 - accuracy: 0.0872 - val_loss: 3.1991 - val_accuracy: 0.1224 - lr: 0.0010
# Epoch 2/50
# 625/625 [==============================] - 11s 18ms/step - loss: 3
50
# 625/625 [==============================] - 10s 17ms/step - loss: 9.3228 - accuracy: 0.0504 - val_loss: 9.4098 - val_accuracy: 0.0498 - lr: 0.0010
# Epoch 20/50
# 625/625 [==============================] - 11s 17ms/step - loss: 9.2793 - accuracy: 0.0553 - val_loss: 9.3744 - val_accuracy: 0.0594 - lr: 0.0010
# Epoch 21/50
# 625/625 [==============================] - 10s 17ms/step - loss: 9.3972 - accuracy: 0.0398 - val_loss: 9.4741 - val_accuracy: 0.0338 - lr: 0.0010
# Epoch 22/50
# 625/625 [==============================] - 10s 16ms/step - loss: 9.5477 - accuracy: 0.0300 - val_loss: 9.9888 - val_accuracy: 0.0206 - lr: 0.0010
# Epoch 23/50
# 625/625 [==============================] - 10s 16ms/step - loss: 9.8055 - accuracy: 0.0199 - val_loss: 9.7799 - val_accuracy: 0.0206 - lr: 1.0000e-04
# Epoch 24/50
# 625/625 [==============================] - 10s 17ms/step - loss: 9.6530 - accuracy: 0.0199 - val_loss: 9.7712 - val_accuracy: 0.0206 - lr: 1.0000e-04
# Epoch 25/50
# 625/625 [==============================] - 10s 17ms/step - loss: 9.6467 - accuracy: 0.0199 - val_loss: 9.7656 - val_accuracy: 0.0204 - lr: 1.0000e-04
# Epoch 26/50
# 625/625 [==============================] - 10s 17ms/step - loss: 9.4487 - accuracy: 0.0207 - val_loss: 9.5382 - val_accuracy: 0.0244 - lr: 1.0000e-04
# Epoch 27/50
# 625/625 [==============================] - 10s 17ms/step - loss: 9.4124 - accuracy: 0.0204 - val_loss: 9.5254 - val_accuracy: 0.0214 - lr: 1.0000e-04
# Epoch 28/50
# 625/625 [==============================] - 10s 16ms/step - loss: 9.4033 - accuracy: 0.0199 - val_loss: 9.5231 - val_accuracy: 0.0218 - lr: 1.0000e-05
# Epoch 29/50
# 625/625 [==============================] - 10s 17ms/step - loss: 9.4008 - accuracy: 0.0201 - val_loss: 9.5205 - val_accuracy: 0.0220 - lr: 1.0000e-05
# Epoch 30/50
# 625/625 [==============================] - 10s 17ms/step - loss: 9.3978 - accuracy: 0.0204 - val_loss: 9.5172 - val_accuracy: 0.0232 - lr: 1.0000e-05
# Epoch 31/50
# 625/625 [==============================] - 11s 17ms/step - loss: 9.3938 - accuracy: 0.0226 - val_loss: 9.5127 - val_accuracy: 0.0248 - lr: 1.0000e-05
# Epoch 32/50
# 625/625 [==============================] - 10s 17ms/step - loss: 9.3883 - accuracy: 0.0262 - val_loss: 9.5063 - val_accuracy: 0.0270 - lr: 1.0000e-05
# 157/157 [==============================] - 1s 7ms/step - loss: 9.3106 - accuracy: 0.0668
# Running experiment with final activation: elu
# Epoch 1/50
# 625/625 [==============================] - 11s 17ms/step - loss: 11.2548 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 0.0010
# Epoch 2/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 0.0010
# Epoch 3/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 0.0010
# Epoch 4/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 0.0010
# Epoch 5/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 0.0010
# Epoch 6/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 0.0010
# Epoch 7/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 1.0000e-04
# Epoch 8/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 1.0000e-04
# Epoch 9/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 1.0000e-04
# Epoch 10/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 1.0000e-04
# Epoch 11/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 1.0000e-04
# Epoch 12/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 1.0000e-05
# Epoch 13/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 1.0000e-05
# Epoch 14/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 1.0000e-05
# Epoch 15/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 1.0000e-05
# Epoch 16/50
# 625/625 [==============================] - 10s 16ms/step - loss: 11.6413 - accuracy: 0.0198 - val_loss: 11.4600 - val_accuracy: 0.0208 - lr: 1.0000e-05
# 157/157 [==============================] - 1s 7ms/step - loss: 11.6050 - accuracy: 0.0200
# Running experiment with final activation: linear
# Epoch 1/50
# 625/625 [==============================] - 11s 17ms/step - loss: 8.8851 - accuracy: 0.0195 - val_loss: 9.1841 - val_accuracy: 0.0218 - lr: 0.0010
# Epoch 2/50
# 625/625 [==============================] - 10s 16ms/step - loss: 8.9834 - accuracy: 0.0195 - val_loss: 9.1841 - val_accuracy: 0.0218 - lr: 0.0010
# Epoch 3/50
# 625/625 [==============================] - 10s 17ms/step - loss: 8.9834 - accuracy: 0.0195 - val_loss: 9.1841 - val_accuracy: 0.0218 - lr: 0.0010
# Epoch 4/50
# 625/625 [==============================] - 10s 17ms/step - loss: 8.9834 - accuracy: 0.0195 - val_loss: 9.1841 - val_accuracy: 0.0218 - lr: 0.0010
# Epoch 5/50
# 625/625 [==============================] - 10s 17ms/step - loss: 8.9834 - accuracy: 0.0195 - val_loss: 9.1841 - val_accuracy: 0.0218 - lr: 0.0010
# Epoch 6/50
# 625/625 [==============================] - 10s 17ms/step - loss: 8.9834 - accuracy: 0.0195 - val_loss: 9.1841 - val_accuracy: 0.0218 - lr: 0.0010
# Epoch 7/50
# 625/625 [==============================] - 11s 17ms/step - loss: 8.9834 - accuracy: 0.0195 - val_loss: 9.1841 - val_accuracy: 0.0218 - lr: 1.0000e-04
# Epoch
 'lr': [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.000100000005, 0.000100000005, 0.000100000005, 0.000100000005, 0.000100000005, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05]}, 'experiment_variable': 'sigmoid', 'loss': 2.253530263900757, 'accuracy': 0.39640000462532043}

# %%
# select the best model
best_final_activation_model = final_activation_results[0]['model']
best_final_activation_model_history = final_activation_results[0]['history']

# set a variable to hold the best final activation method
best_final_activation_method = final_activation_results[0]['experiment_variable'] 

# print the top result
print(final_activation_results[0])

# print the best activation method
print(f'Best final activation method: {best_final_activation_method}')
# Out:
# {'experiment': 'final_activation', 'model': <keras.src.engine.functional.Functional object at 0x300d67a90>, 'history': {'loss': [3.400604009628296, 2.9641294479370117, 2.704977035522461, 2.4739291667938232, 2.2924506664276123, 2.12772274017334, 1.960795521736145, 1.820186734199524, 1.6794322729110718, 1.5619477033615112, 1.4273128509521484, 1.3281993865966797, 1.2270328998565674, 1.1188075542449951, 0.7542967796325684, 0.6679926514625549, 0.6248185634613037, 0.5901595950126648, 0.5587098002433777, 0.506889283657074, 0.5001556873321533, 0.4962541460990906, 0.49270570278167725, 0.4895099997520447], 'accuracy': [0.09395000338554382, 0.18970000743865967, 0.24809999763965607, 0.30125001072883606, 0.341949999332428, 0.3852500021457672, 0.4250499904155731, 0.46415001153945923, 0.5011500120162964, 0.5288000106811523, 0.5674999952316284, 0.5953999757766724, 0.6172999739646912, 0.6519500017166138, 0.7703999876976013, 0.7970499992370605, 0.8112999796867371, 0.8251000046730042, 0.8356500267982483, 0.8555499911308289, 0.8590499758720398, 0.8605999946594238, 0.861050009727478, 0.8627499938011169], 'val_loss': [3.1809515953063965, 2.9002182483673096, 2.7724356651306152, 2.5094614028930664, 2.4060449600219727, 2.414555072784424, 2.292386293411255, 2.3185856342315674, 2.2619848251342773, 2.3058276176452637, 2.4416427612304688, 2.4512157440185547, 2.5249125957489014, 2.646176815032959, 2.690500497817993, 2.7995312213897705, 2.880060911178589, 2.9467453956604004, 3.047135591506958, 3.0556390285491943, 3.0753841400146484, 3.08890438079834, 3.1044366359710693, 3.1150763034820557], 'val_accuracy': [0.15520000457763672, 0.2029999941587448, 0.25040000677108765, 0.30379998683929443, 0.3294000029563904, 0.32600000500679016, 0.36640000343322754, 0.37400001287460327, 0.38019999861717224, 0.38600000739097595, 0.37040001153945923, 0.3813999891281128, 0.384799987077713, 0.39259999990463257, 0.4174000024795532, 0.41600000858306885, 0.4115999937057495, 0.4083999991416931, 0.40880000591278076, 0.40860000252723694, 0.4090000092983246, 0.40779998898506165, 0.40779998898506165, 0.40720000863075256], 'lr': [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.000100000005, 0.000100000005, 0.000100000005, 0.000100000005, 0.000100000005, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05]}, 'experiment_variable': 'sigmoid', 'loss': 2.253530263900757, 'accuracy': 0.39640000462532043}
# Best final activation method: sigmoid

# %%
# evaluate the best model
evaluate_model(best_final_activation_model, best_final_activation_model_history, test_images_block_1, test_labels_block_1)
# Out:
# 157/157 [==============================] - 1s 7ms/step - loss: 2.2535 - accuracy: 0.3964
# Test loss:  2.253530263900757
# Test accuracy:  0.39640000462532043
# 157/157 [==============================] - 1s 7ms/step
# Confusion matrix:
# [[41  9  3 ...  0  7  0]
#  [ 5 66  1 ...  0  5  0]
#  [10  3 42 ...  1 14  0]
#  ...
#  [ 2  2  0 ... 22  0  1]
#  [10  7  7 ...  0 56  1]
#  [ 2  1  0 ...  0  0 12]]
# 157/157 [==============================] - 1s 7ms/step
# 0.3964
#               precision    recall  f1-score   support
#
#            0       0.35      0.41      0.38       100
#            1       0.62      0.66      0.64       100
#            2       0.62      0.42      0.50       100
#            3       0.35      0.23      0.28       100
#            4       0.19      0.26      0.22       100
#            5       0.49      0.55      0.52       100
#            6       0.36      0.25      0.30       100
#            7       0.19      0.33      0.24       100
#            8       0.28      0.35      0.31       100
#            9       0.63      0.72      0.67       100
#           10       0.48      0.40      0.44       100
#           11       0.34      0.33      0.34       100
#           12       0.45      0.25      0.32       100
#           13       0.47      0.45      0.46       100
#           14       0.50      0.18      0.26       100
#           15       0.31      0.19      0.24       100
#           16       0.68      0.66      0.67       100
#           17       0.19      0.16      0.17       100
#           18       0.49      0.31      0.38       100
#           19       0.54      0.37      0.44       100
#           20       0.16      0.05      0.08       100
#           21       0.23      0.37      0.29       100
#           22       0.46      0.27      0.34       100
#           23       0.28      0.44      0.34       100
#           24       0.57      0.59      0.58       100
#           25       0.41      0.37      0.39       100
#           26       0.37      0.25      0.30       100
#           27       0.51      0.37      0.43       100
#           28       0.42      0.52      0.47       100
#           29       0.20      0.17      0.18       100
#           30       0.43      0.33      0.38       100
#           31       0.65      0.67      0.66       100
#           32       0.51      0.58      0.54       100
#           33       0.50      0.62      0.55       100
#           34       0.31      0.16      0.21       100
#           35       0.26      0.56      0.35       100
#           36       0.38      0.43      0.41       100
#           37       0.28      0.36      0.31       100
#           38       0.32      0.53      0.40       100
#           39       0.43      0.42      0.43       100
#           40       0.61      0.47      0.53       100
#           41       0.37      0.32      0.34       100
#           42       0.57      0.55      0.56       100
#           43       0.37      0.65      0.47       100
#           44       0.30      0.40      0.34       100
#           45       0.52      0.40      0.45       100
#           46       0.30      0.59      0.40       100
#           47       0.31      0.22      0.26       100
#           48       0.64      0.56      0.60       100
#           49       0.40      0.12      0.18       100
#
#     accuracy                           0.40      5000
#    macro avg       0.41      0.40      0.39      5000
# weighted avg       0.41      0.40      0.39      5000

# %% [markdown]
# #### 6. Investigate the use of skip connections in network design.

# %%
# create a model that uses the skip connection, with the best activation and final activation methods
skip_model = create_model(activation=best_activation_method, 
                          loss_function=best_loss_function,
                          final_activation=best_final_activation_method, 
                          use_skip=True)

# train the model
skip_model_history = skip_model.fit(train_images_block_1, train_labels_block_1, 
                                    batch_size=BATCH_SIZE, 
                                    epochs=EPOCHS, 
                                    validation_split=VALIDATION_SPLIT, 
                                    callbacks=callbacks)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 11s 17ms/step - loss: 3.2443 - accuracy: 0.1357 - val_loss: 2.8449 - val_accuracy: 0.2210 - lr: 0.0010
# Epoch 2/50
# 625/625 [==============================] - 11s 17ms/step - loss: 2.6161 - accuracy: 0.2754 - val_loss: 2.4678 - val_accuracy: 0.3136 - lr: 0.0010
# Epoch 3/50
# 625/625 [==============================] - 11s 17ms/step - loss: 2.2251 - accuracy: 0.3749 - val_loss: 2.2239 - val_accuracy: 0.3832 - lr: 0.0010
# Epoch 4/50
# 625/625 [==============================] - 11s 18ms/step - loss: 1.9318 - accuracy: 0.4424 - val_loss: 2.1115 - val_accuracy: 0.3964 - lr: 0.0010
# Epoch 5/50
# 625/625 [==============================] - 11s 17ms/step - loss: 1.7030 - accuracy: 0.4999 - val_loss: 2.1125 - val_accuracy: 0.4182 - lr: 0.0010
# Epoch 6/50
# 625/625 [==============================] - 11s 17ms/step - loss: 1.4901 - accuracy: 0.5525 - val_loss: 2.1089 - val_accuracy: 0.4286 - lr: 0.0010
# Epoch 7/50
# 625/625 [==============================] - 11s 17ms/step - loss: 1.2903 - accuracy: 0.6107 - val_loss: 2.1009 - val_accuracy: 0.4476 - lr: 0.0010
# Epoch 8/50
# 625/625 [==============================] - 11s 17ms/step - loss: 1.0903 - accuracy: 0.6679 - val_loss: 2.2699 - val_accuracy: 0.4382 - lr: 0.0010
# Epoch 9/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.9329 - accuracy: 0.7032 - val_loss: 2.4268 - val_accuracy: 0.4324 - lr: 0.0010
# Epoch 10/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.7707 - accuracy: 0.7521 - val_loss: 2.6490 - val_accuracy: 0.4222 - lr: 0.0010
# Epoch 11/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.6402 - accuracy: 0.7928 - val_loss: 2.7602 - val_accuracy: 0.4248 - lr: 0.0010
# Epoch 12/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5383 - accuracy: 0.8245 - val_loss: 3.1169 - val_accuracy: 0.4172 - lr: 0.0010
# Epoch 13/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.2369 - accuracy: 0.9316 - val_loss: 3.1016 - val_accuracy: 0.4492 - lr: 1.0000e-04
# Epoch 14/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.1463 - accuracy: 0.9645 - val_loss: 3.2469 - val_accuracy: 0.4572 - lr: 1.0000e-04
# Epoch 15/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1107 - accuracy: 0.9759 - val_loss: 3.4315 - val_accuracy: 0.4554 - lr: 1.0000e-04
# Epoch 16/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.0860 - accuracy: 0.9825 - val_loss: 3.6509 - val_accuracy: 0.4556 - lr: 1.0000e-04
# Epoch 17/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.0665 - accuracy: 0.9876 - val_loss: 3.8824 - val_accuracy: 0.4580 - lr: 1.0000e-04
# Epoch 18/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.0470 - accuracy: 0.9935 - val_loss: 3.8886 - val_accuracy: 0.4574 - lr: 1.0000e-05
# Epoch 19/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.0443 - accuracy: 0.9941 - val_loss: 3.9272 - val_accuracy: 0.4558 - lr: 1.0000e-05
# Epoch 20/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.0424 - accuracy: 0.9947 - val_loss: 3.9732 - val_accuracy: 0.4550 - lr: 1.0000e-05
# Epoch 21/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.0406 - accuracy: 0.9949 - val_loss: 4.0141 - val_accuracy: 0.4570 - lr: 1.0000e-05
# Epoch 22/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.0387 - accuracy: 0.9954 - val_loss: 4.0424 - val_accuracy: 0.4568 - lr: 1.0000e-05

# %%
# evaluate the model
evaluate_model(skip_model, skip_model_history.history, test_images_block_1, test_labels_block_1)

# get model loss and accuracy
skip_model_loss, skip_model_accuracy = skip_model.evaluate(test_images_block_1, test_labels_block_1)
# Out:
# 157/157 [==============================] - 1s 6ms/step - loss: 2.1046 - accuracy: 0.4348
# Test loss:  2.104644536972046
# Test accuracy:  0.43479999899864197
# 157/157 [==============================] - 1s 6ms/step
# Confusion matrix:
# [[27 13  8 ...  0  4  0]
#  [ 4 68  2 ...  0  6  1]
#  [ 3  2 52 ...  0 20  0]
#  ...
#  [ 0  1  0 ... 26  3  1]
#  [ 7  7 14 ...  0 57  1]
#  [ 1  0  0 ...  4  1 62]]
# 157/157 [==============================] - 1s 7ms/step
# 0.4334
#               precision    recall  f1-score   support
#
#            0       0.44      0.27      0.34       100
#            1       0.62      0.68      0.65       100
#            2       0.50      0.52      0.51       100
#            3       0.38      0.27      0.31       100
#            4       0.23      0.30      0.26       100
#            5       0.45      0.68      0.54       100
#            6       0.43      0.48      0.45       100
#            7       0.17      0.11      0.13       100
#            8       0.30      0.46      0.36       100
#            9       0.49      0.77      0.60       100
#           10       0.43      0.48      0.45       100
#           11       0.45      0.27      0.34       100
#           12       0.41      0.54      0.47       100
#           13       0.50      0.39      0.44       100
#           14       0.45      0.30      0.36       100
#           15       0.33      0.39      0.36       100
#           16       0.85      0.61      0.71       100
#           17       0.31      0.13      0.18       100
#           18       0.45      0.34      0.39       100
#           19       0.47      0.54      0.50       100
#           20       0.16      0.21      0.18       100
#           21       0.35      0.44      0.39       100
#           22       0.41      0.46      0.43       100
#           23       0.60      0.27      0.37       100
#           24       0.57      0.63      0.60       100
#           25       0.48      0.32      0.38       100
#           26       0.45      0.42      0.44       100
#           27       0.49      0.63      0.55       100
#           28       0.43      0.60      0.50       100
#           29       0.19      0.25      0.22       100
#           30       0.42      0.41      0.42       100
#           31       0.66      0.58      0.62       100
#           32       0.61      0.49      0.54       100
#           33       0.66      0.58      0.62       100
#           34       0.36      0.25      0.29       100
#           35       0.33      0.58      0.42       100
#           36       0.51      0.36      0.42       100
#           37       0.32      0.32      0.32       100
#           38       0.37      0.32      0.34       100
#           39       0.46      0.41      0.43       100
#           40       0.66      0.58      0.62       100
#           41       0.51      0.41      0.45       100
#           42       0.57      0.60      0.59       100
#           43       0.47      0.61      0.53       100
#           44       0.30      0.38      0.33       100
#           45       0.62      0.26      0.37       100
#           46       0.54      0.32      0.40       100
#           47       0.32      0.26      0.29       100
#           48       0.48      0.57      0.52       100
#           49       0.41      0.62      0.49       100
#
#     accuracy                           0.43      5000
#    macro avg       0.45      0.43      0.43      5000
# weighted avg       0.45      0.43      0.43      5000
# 157/157 [==============================] - 1s 7ms/step - loss: 2.1046 - accuracy: 0.4348

# %%
# create a model with all the best parameters
test_model = create_model(activation=best_activation_method, 
                          loss_function=best_loss_function,
                          final_activation=best_final_activation_method, 
                          use_skip=True)

# train the model
test_model_history = test_model.fit(train_images_block_1, train_labels_block_1, 
                                    batch_size=BATCH_SIZE, 
                                    epochs=EPOCHS, 
                                    validation_split=VALIDATION_SPLIT, 
                                    callbacks=callbacks)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 11s 18ms/step - loss: 3.2577 - accuracy: 0.1347 - val_loss: 2.8874 - val_accuracy: 0.2188 - lr: 0.0010
# Epoch 2/50
# 625/625 [==============================] - 11s 18ms/step - loss: 2.6243 - accuracy: 0.2718 - val_loss: 2.4710 - val_accuracy: 0.3176 - lr: 0.0010
# Epoch 3/50
# 625/625 [==============================] - 11s 18ms/step - loss: 2.2427 - accuracy: 0.3637 - val_loss: 2.2905 - val_accuracy: 0.3748 - lr: 0.0010
# Epoch 4/50
# 625/625 [==============================] - 11s 18ms/step - loss: 1.9616 - accuracy: 0.4336 - val_loss: 2.1872 - val_accuracy: 0.3886 - lr: 0.0010
# Epoch 5/50
# 625/625 [==============================] - 11s 18ms/step - loss: 1.7084 - accuracy: 0.4979 - val_loss: 2.1839 - val_accuracy: 0.4014 - lr: 0.0010
# Epoch 6/50
# 625/625 [==============================] - 11s 18ms/step - loss: 1.4931 - accuracy: 0.5550 - val_loss: 2.1549 - val_accuracy: 0.4262 - lr: 0.0010
# Epoch 7/50
# 625/625 [==============================] - 11s 18ms/step - loss: 1.2844 - accuracy: 0.6087 - val_loss: 2.2186 - val_accuracy: 0.4154 - lr: 0.0010
# Epoch 8/50
# 625/625 [==============================] - 11s 18ms/step - loss: 1.0970 - accuracy: 0.6595 - val_loss: 2.2887 - val_accuracy: 0.4244 - lr: 0.0010
# Epoch 9/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.9193 - accuracy: 0.7127 - val_loss: 2.5398 - val_accuracy: 0.4104 - lr: 0.0010
# Epoch 10/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.7690 - accuracy: 0.7537 - val_loss: 2.7456 - val_accuracy: 0.4126 - lr: 0.0010
# Epoch 11/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.6449 - accuracy: 0.7939 - val_loss: 2.9055 - val_accuracy: 0.4184 - lr: 0.0010
# Epoch 12/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.2942 - accuracy: 0.9143 - val_loss: 2.8952 - val_accuracy: 0.4404 - lr: 1.0000e-04
# Epoch 13/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.1984 - accuracy: 0.9495 - val_loss: 3.0572 - val_accuracy: 0.4446 - lr: 1.0000e-04
# Epoch 14/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.1545 - accuracy: 0.9627 - val_loss: 3.2849 - val_accuracy: 0.4406 - lr: 1.0000e-04
# Epoch 15/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.1221 - accuracy: 0.9720 - val_loss: 3.4601 - val_accuracy: 0.4460 - lr: 1.0000e-04
# Epoch 16/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.0975 - accuracy: 0.9794 - val_loss: 3.7248 - val_accuracy: 0.4466 - lr: 1.0000e-04
# Epoch 17/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.0694 - accuracy: 0.9883 - val_loss: 3.7179 - val_accuracy: 0.4480 - lr: 1.0000e-05
# Epoch 18/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.0659 - accuracy: 0.9894 - val_loss: 3.7557 - val_accuracy: 0.4478 - lr: 1.0000e-05
# Epoch 19/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.0633 - accuracy: 0.9900 - val_loss: 3.7935 - val_accuracy: 0.4464 - lr: 1.0000e-05
# Epoch 20/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.0609 - accuracy: 0.9910 - val_loss: 3.8314 - val_accuracy: 0.4456 - lr: 1.0000e-05
# Epoch 21/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.0584 - accuracy: 0.9913 - val_loss: 3.8672 - val_accuracy: 0.4464 - lr: 1.0000e-05

# %%
# get the model loss and accuracy
test_model_loss, test_model_accuracy = test_model.evaluate(test_images_block_1, test_labels_block_1)
# Out:
# 157/157 [==============================] - 1s 7ms/step - loss: 2.1229 - accuracy: 0.4288

# %% [markdown]
# #### 7. Save the best performing model for the demo notebook and use later.

# %%
# combine the results of the three models, so we can order them by accuracy
combined_results = activation_results + final_activation_results + loss_function_results+[{'experiment': 'skip_layer','model': skip_model, 'history': skip_model_history.history, 'accuracy': skip_model_accuracy, 'loss': skip_model_loss, 'experiment_variable': 'skip_layer'}] + [{'experiment': 'all_best_params','model': test_model, 'history': test_model_history.history, 'accuracy': test_model_accuracy, 'loss': test_model_loss, 'experiment_variable': 'all_best_params'}]

# sort the results by accuracy
combined_results = sorted(combined_results, key=lambda x: x['accuracy'], reverse=True)

# save the best model
best_basic_model = combined_results[0]['model']

# save the model to disk
os.makedirs('models/Part2', exist_ok=True)
best_basic_model.save(MODEL_DIR_PATH+'/best_basic_model.keras')

# save the comibined results to csv
results_df = pd.DataFrame(combined_results)
results_df.to_csv(MODEL_DIR_PATH+'/results.csv', index=False)

# # save the best model history
# save_to_disk(combined_results[0]['history'], MODEL_DIR_PATH+'/best_basic_model_history.pkl')

# # save the combined results
# os.makedirs('results/Part2', exist_ok=True)
# save_to_disk(combined_results, MODEL_DIR_PATH+'/combined_results.pkl')

# %%
# plot a comparison of the combined results
plt.figure(figsize=(10, 6))
for result in combined_results:
    plt.plot(result['history']['accuracy'], label=f"{result['experiment_variable']}: {result['accuracy']:.2f}")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Comparison of Model Accuracy')
plt.legend()
plt.show()

# plot a comparison of the combined results
plt.figure(figsize=(10, 6))
for result in combined_results:
    plt.plot(result['history']['loss'], label=f"{result['experiment_variable']}: {result['loss']:.2f}")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Comparison of Model Loss')
plt.legend()
plt.show()

# evaluate the best model
evaluate_model(best_basic_model, combined_results[0]['history'], test_images_block_1, test_labels_block_1)
# Out:
# 157/157 [==============================] - 1s 7ms/step - loss: 2.1046 - accuracy: 0.4348
# Test loss:  2.104644536972046
# Test accuracy:  0.43479999899864197
# 157/157 [==============================] - 1s 7ms/step
# Confusion matrix:
# [[27 13  8 ...  0  4  0]
#  [ 4 68  2 ...  0  6  1]
#  [ 3  2 52 ...  0 20  0]
#  ...
#  [ 0  1  0 ... 26  3  1]
#  [ 7  7 14 ...  0 57  1]
#  [ 1  0  0 ...  4  1 62]]
# 157/157 [==============================] - 1s 7ms/step
# 0.4334
#               precision    recall  f1-score   support
#
#            0       0.44      0.27      0.34       100
#            1       0.62      0.68      0.65       100
#            2       0.50      0.52      0.51       100
#            3       0.38      0.27      0.31       100
#            4       0.23      0.30      0.26       100
#            5       0.45      0.68      0.54       100
#            6       0.43      0.48      0.45       100
#            7       0.17      0.11      0.13       100
#            8       0.30      0.46      0.36       100
#            9       0.49      0.77      0.60       100
#           10       0.43      0.48      0.45       100
#           11       0.45      0.27      0.34       100
#           12       0.41      0.54      0.47       100
#           13       0.50      0.39      0.44       100
#           14       0.45      0.30      0.36       100
#           15       0.33      0.39      0.36       100
#           16       0.85      0.61      0.71       100
#           17       0.31      0.13      0.18       100
#           18       0.45      0.34      0.39       100
#           19       0.47      0.54      0.50       100
#           20       0.16      0.21      0.18       100
#           21       0.35      0.44      0.39       100
#           22       0.41      0.46      0.43       100
#           23       0.60      0.27      0.37       100
#           24       0.57      0.63      0.60       100
#           25       0.48      0.32      0.38       100
#           26       0.45      0.42      0.44       100
#           27       0.49      0.63      0.55       100
#           28       0.43      0.60      0.50       100
#           29       0.19      0.25      0.22       100
#           30       0.42      0.41      0.42       100
#           31       0.66      0.58      0.62       100
#           32       0.61      0.49      0.54       100
#           33       0.66      0.58      0.62       100
#           34       0.36      0.25      0.29       100
#           35       0.33      0.58      0.42       100
#           36       0.51      0.36      0.42       100
#           37       0.32      0.32      0.32       100
#           38       0.37      0.32      0.34       100
#           39       0.46      0.41      0.43       100
#           40       0.66      0.58      0.62       100
#           41       0.51      0.41      0.45       100
#           42       0.57      0.60      0.59       100
#           43       0.47      0.61      0.53       100
#           44       0.30      0.38      0.33       100
#           45       0.62      0.26      0.37       100
#           46       0.54      0.32      0.40       100
#           47       0.32      0.26      0.29       100
#           48       0.48      0.57      0.52       100
#           49       0.41      0.62      0.49       100
#
#     accuracy                           0.43      5000
#    macro avg       0.45      0.43      0.43      5000
# weighted avg       0.45      0.43      0.43      5000

# %% [markdown]
# ### Autoencoder Modelling: For Block 1 Images
# Building on your best performing model to this point, construct an autoencoder model to attempt
# to reproduce input images. Discuss the appropriate use of loss functions and metrics for
# evaluation.
# Save the model notebook for the demo notebook and use later.

# %%
# load the best model
best_basic_model = load_model(MODEL_DIR_PATH+'/best_basic_model.keras')

# %%
evaluate_model(best_basic_model, combined_results[0]['history'], test_images_block_1, test_labels_block_1)
# Out:
# 157/157 [==============================] - 1s 7ms/step - loss: 2.1046 - accuracy: 0.4348
# Test loss:  2.104644536972046
# Test accuracy:  0.43479999899864197
# 157/157 [==============================] - 1s 7ms/step
# Confusion matrix:
# [[27 13  8 ...  0  4  0]
#  [ 4 68  2 ...  0  6  1]
#  [ 3  2 52 ...  0 20  0]
#  ...
#  [ 0  1  0 ... 26  3  1]
#  [ 7  7 14 ...  0 57  1]
#  [ 1  0  0 ...  4  1 62]]
# 157/157 [==============================] - 1s 8ms/step
# 0.4334
#               precision    recall  f1-score   support
#
#            0       0.44      0.27      0.34       100
#            1       0.62      0.68      0.65       100
#            2       0.50      0.52      0.51       100
#            3       0.38      0.27      0.31       100
#            4       0.23      0.30      0.26       100
#            5       0.45      0.68      0.54       100
#            6       0.43      0.48      0.45       100
#            7       0.17      0.11      0.13       100
#            8       0.30      0.46      0.36       100
#            9       0.49      0.77      0.60       100
#           10       0.43      0.48      0.45       100
#           11       0.45      0.27      0.34       100
#           12       0.41      0.54      0.47       100
#           13       0.50      0.39      0.44       100
#           14       0.45      0.30      0.36       100
#           15       0.33      0.39      0.36       100
#           16       0.85      0.61      0.71       100
#           17       0.31      0.13      0.18       100
#           18       0.45      0.34      0.39       100
#           19       0.47      0.54      0.50       100
#           20       0.16      0.21      0.18       100
#           21       0.35      0.44      0.39       100
#           22       0.41      0.46      0.43       100
#           23       0.60      0.27      0.37       100
#           24       0.57      0.63      0.60       100
#           25       0.48      0.32      0.38       100
#           26       0.45      0.42      0.44       100
#           27       0.49      0.63      0.55       100
#           28       0.43      0.60      0.50       100
#           29       0.19      0.25      0.22       100
#           30       0.42      0.41      0.42       100
#           31       0.66      0.58      0.62       100
#           32       0.61      0.49      0.54       100
#           33       0.66      0.58      0.62       100
#           34       0.36      0.25      0.29       100
#           35       0.33      0.58      0.42       100
#           36       0.51      0.36      0.42       100
#           37       0.32      0.32      0.32       100
#           38       0.37      0.32      0.34       100
#           39       0.46      0.41      0.43       100
#           40       0.66      0.58      0.62       100
#           41       0.51      0.41      0.45       100
#           42       0.57      0.60      0.59       100
#           43       0.47      0.61      0.53       100
#           44       0.30      0.38      0.33       100
#           45       0.62      0.26      0.37       100
#           46       0.54      0.32      0.40       100
#           47       0.32      0.26      0.29       100
#           48       0.48      0.57      0.52       100
#           49       0.41      0.62      0.49       100
#
#     accuracy                           0.43      5000
#    macro avg       0.45      0.43      0.43      5000
# weighted avg       0.45      0.43      0.43      5000

# %% [markdown]
# #### Basic Decoder

# %%
# from tensorflow.keras.layers import Dense, Reshape, Input
# from tensorflow.keras.models import Model

# def create_decoder(latent_dim=50, 
#                    activation='relu', 
#                    final_activation='sigmoid',
#                    output_shape=(32, 32, 3)):
#     # Input latent representation
#     latent_inputs = Input(shape=(latent_dim,))
    
#     # First hidden layer
#     dense_one = Dense(32, activation=activation)(latent_inputs)
#     # Second hidden layer
#     dense_two = Dense(64, activation=activation)(dense_one)
#     # Third hidden layer
#     dense_three = Dense(128, activation=activation)(dense_two)
#     # Fourth hidden layer
#     dense_four = Dense(256, activation=activation)(dense_three)
#     # Fifth hidden layer
#     dense_five = Dense(512, activation=activation)(dense_four)

#     # Output layer (reshaping back to original input shape)
#     output_layer = Dense(output_shape[0] * output_shape[1] * output_shape[2], 
#                          activation=final_activation)(dense_five)
#     outputs = Reshape(output_shape)(output_layer)

#     decoder = Model(latent_inputs, outputs)
#     return decoder

# %% [markdown]
# #### CNN Decoder

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Reshape, Conv2DTranspose, UpSampling2D, Conv2D

def create_decoder(input_dim=50, 
                   activation='relu',
                   optimizer='adam',
                   final_activation='sigmoid',
                   loss_function='mse'):
    """
    Creates a decoder model to reconstruct the original image from encoded features.
    
    Parameters:
    - input_dim: The dimensionality of the encoded input vector.
    - activation: Activation function for hidden layers.
    - optimizer: Optimizer to use for compiling the model.
    - final_activation: Activation function for the output layer.
    - loss_function: Loss function to use for compiling the model.
    
    Returns:
    - A compiled Keras decoder model.
    """
    # Input layer for the encoded vector
    inputs = Input(shape=(input_dim,))
    
    # Dense layers to expand the encoded vector back
    dense1 = Dense(256, activation=activation)(inputs)
    dense2 = Dense(128, activation=activation)(dense1)
    dense3 = Dense(4 * 4 * 128, activation=activation)(dense2)
    
    # Reshape to match the feature map shape
    reshaped = Reshape((4, 4, 128))(dense3)
    
    # Decoder layers (adjusted for 32x32x3 output)
    conv1_transpose = Conv2DTranspose(128, (3, 3), activation=activation, padding='same')(reshaped)
    up1 = UpSampling2D((2, 2))(conv1_transpose)  # 8x8
    
    conv2_transpose = Conv2DTranspose(64, (3, 3), activation=activation, padding='same')(up1)
    up2 = UpSampling2D((2, 2))(conv2_transpose)  # 16x16
    
    conv3_transpose = Conv2DTranspose(32, (3, 3), activation=activation, padding='same')(up2)
    up3 = UpSampling2D((2, 2))(conv3_transpose)  # 32x32
    
    # Final convolution layer to match the original image dimensions
    output = Conv2D(3, (3, 3), activation=final_activation, padding='same')(up3)
    
    # Create and compile the model
    decoder = Model(inputs, output)
    decoder.compile(optimizer=optimizer, loss=loss_function)
    
    return decoder

# %%
# load the best basic model, from disk
# encoder_model = load_model('models/Part1/best_basic_model.keras')

# %%
# create an autoencoder model to reconstruct the images based on the best basic model
decoder = create_decoder(input_dim=50, activation='leaky_relu', final_activation='sigmoid', loss_function='mse')
decoder.summary()
# Out:
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 50)]              0
#
#  dense_70 (Dense)            (None, 256)               13056
#
#  dense_71 (Dense)            (None, 128)               32896
#
#  dense_72 (Dense)            (None, 2048)              264192
#
#  reshape (Reshape)           (None, 4, 4, 128)         0
#
#  conv2d_transpose (Conv2DTr  (None, 4, 4, 128)         147584
#  anspose)
#
#  up_sampling2d (UpSampling2  (None, 8, 8, 128)         0
#  D)
#
#  conv2d_transpose_1 (Conv2D  (None, 8, 8, 64)          73792
#  Transpose)
#
#  up_sampling2d_1 (UpSamplin  (None, 16, 16, 64)        0
#  g2D)
#
#  conv2d_transpose_2 (Conv2D  (None, 16, 16, 32)        18464
#  Transpose)
#
#  up_sampling2d_2 (UpSamplin  (None, 32, 32, 32)        0
#  g2D)
#
#  conv2d_51 (Conv2D)          (None, 32, 32, 3)         867
#
# =================================================================
# Total params: 550851 (2.10 MB)
# Trainable params: 550851 (2.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Combine encoder and decoder into an autoencoder
encoded_input = best_basic_model.input
encoded_output = best_basic_model(encoded_input)  
decoded_output = decoder(encoded_output)  

# Create the model
autoencoder = Model(inputs=encoded_input, outputs=decoded_output)

# Compile the model
autoencoder.compile(optimizer=OPTIMIZER, loss='mse')

# Display the autoencoder model summary
autoencoder.summary()
# Out:
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  model_14 (Functional)       (None, 50)                286898
#
#  model_17 (Functional)       (None, 32, 32, 3)         550851
#
# =================================================================
# Total params: 837749 (3.20 MB)
# Trainable params: 837749 (3.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# train the autoencoder model
autoencoder_history = autoencoder.fit(train_images_block_1, train_images_block_1, 
                                      batch_size=BATCH_SIZE, 
                                      epochs=EPOCHS, 
                                      validation_split=VALIDATION_SPLIT, 
                                      callbacks=callbacks)

# save the autoencoder model
autoencoder.save(MODEL_DIR_PATH+'/basic_autoencoder_model.keras')
# Out:
# Epoch 1/50
# 625/625 [==============================] - 23s 36ms/step - loss: 0.0283 - val_loss: 0.0223 - lr: 0.0010
# Epoch 2/50
# 625/625 [==============================] - 23s 36ms/step - loss: 0.0204 - val_loss: 0.0196 - lr: 0.0010
# Epoch 3/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0184 - val_loss: 0.0180 - lr: 0.0010
# Epoch 4/50
# 625/625 [==============================] - 21s 34ms/step - loss: 0.0176 - val_loss: 0.0175 - lr: 0.0010
# Epoch 5/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0170 - val_loss: 0.0174 - lr: 0.0010
# Epoch 6/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0165 - val_loss: 0.0164 - lr: 0.0010
# Epoch 7/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0159 - val_loss: 0.0161 - lr: 0.0010
# Epoch 8/50
# 625/625 [==============================] - 21s 34ms/step - loss: 0.0157 - val_loss: 0.0159 - lr: 0.0010
# Epoch 9/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0155 - val_loss: 0.0159 - lr: 0.0010
# Epoch 10/50
# 625/625 [==============================] - 22s 36ms/step - loss: 0.0153 - val_loss: 0.0156 - lr: 0.0010
# Epoch 11/50
# 625/625 [==============================] - 23s 36ms/step - loss: 0.0151 - val_loss: 0.0155 - lr: 0.0010
# Epoch 12/50
# 625/625 [==============================] - 23s 37ms/step - loss: 0.0149 - val_loss: 0.0156 - lr: 0.0010
# Epoch 13/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0148 - val_loss: 0.0153 - lr: 0.0010
# Epoch 14/50
# 625/625 [==============================] - 23s 36ms/step - loss: 0.0146 - val_loss: 0.0151 - lr: 0.0010
# Epoch 15/50
# 625/625 [==============================] - 23s 36ms/step - loss: 0.0145 - val_loss: 0.0150 - lr: 0.0010
# Epoch 16/50
# 625/625 [==============================] - 23s 37ms/step - loss: 0.0143 - val_loss: 0.0150 - lr: 0.0010
# Epoch 17/50
# 625/625 [==============================] - 22s 36ms/step - loss: 0.0142 - val_loss: 0.0149 - lr: 0.0010
# Epoch 18/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0140 - val_loss: 0.0147 - lr: 0.0010
# Epoch 19/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0138 - val_loss: 0.0151 - lr: 0.0010
# Epoch 20/50
# 625/625 [==============================] - 22s 36ms/step - loss: 0.0138 - val_loss: 0.0147 - lr: 0.0010
# Epoch 21/50
# 625/625 [==============================] - 23s 37ms/step - loss: 0.0136 - val_loss: 0.0147 - lr: 0.0010
# Epoch 22/50
# 625/625 [==============================] - 23s 37ms/step - loss: 0.0136 - val_loss: 0.0148 - lr: 0.0010
# Epoch 23/50
# 625/625 [==============================] - 22s 36ms/step - loss: 0.0134 - val_loss: 0.0144 - lr: 0.0010
# Epoch 24/50
# 625/625 [==============================] - 22s 36ms/step - loss: 0.0133 - val_loss: 0.0144 - lr: 0.0010
# Epoch 25/50
# 625/625 [==============================] - 23s 36ms/step - loss: 0.0132 - val_loss: 0.0144 - lr: 0.0010
# Epoch 26/50
# 625/625 [==============================] - 23s 37ms/step - loss: 0.0131 - val_loss: 0.0147 - lr: 0.0010
# Epoch 27/50
# 625/625 [==============================] - 24s 38ms/step - loss: 0.0131 - val_loss: 0.0145 - lr: 0.0010
# Epoch 28/50
# 625/625 [==============================] - 24s 38ms/step - loss: 0.0130 - val_loss: 0.0147 - lr: 0.0010

# %%
# display the decoded images
decoded_images = autoencoder.predict(test_images_block_1)

# display the first 10 images
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 4))
for i in range(10):
    # display original
    ax = plt.subplot(2, 10, i + 1)
    plt.imshow(test_images_block_1[i])
    # get the label names from the label encoder
    # ax.set_title(le.inverse_transform([np.argmax(test_labels_block_1[i])]))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, 10, i + 1 + 10)
    plt.imshow(decoded_images[i])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()
# Out:
# 157/157 [==============================] - 2s 13ms/step

# %% [markdown]
# ### Transfer Learning for Block 2 Images
# Using the two models saved above, investigate the use of transfer learning to build a network for
# Block 2 images. Compare results for Transfer Learning based implementations to those for afromscratch implementation equivalent to the transferred model.

# %% [markdown]
# #### Transfer Learning from Basic Model Phase

# %%
# Load the pre-trained models
best_basic_model = load_model(MODEL_DIR_PATH+'/best_basic_model.keras')
autoencoder = load_model(MODEL_DIR_PATH+'/basic_autoencoder_model.keras')

# %%
best_basic_model.summary()
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 32, 32, 3)]          0         []
#
#  conv2d_42 (Conv2D)          (None, 32, 32, 32)           896       ['input_15[0][0]']
#
#  max_pooling2d_42 (MaxPooli  (None, 16, 16, 32)           0         ['conv2d_42[0][0]']
#  ng2D)
#
#  conv2d_43 (Conv2D)          (None, 16, 16, 64)           18496     ['max_pooling2d_42[0][0]']
#
#  max_pooling2d_43 (MaxPooli  (None, 8, 8, 64)             0         ['conv2d_43[0][0]']
#  ng2D)
#
#  conv2d_44 (Conv2D)          (None, 8, 8, 128)            73856     ['max_pooling2d_43[0][0]']
#
#  max_pooling2d_44 (MaxPooli  (None, 4, 4, 128)            0         ['conv2d_44[0][0]']
#  ng2D)
#
#  flatten_14 (Flatten)        (None, 2048)                 0         ['max_pooling2d_44[0][0]']
#
#  dense_56 (Dense)            (None, 64)                   131136    ['flatten_14[0][0]']
#
#  dense_58 (Dense)            (None, 128)                  8320      ['dense_56[0][0]']
#
#  dense_57 (Dense)            (None, 128)                  8320      ['dense_56[0][0]']
#
#  add (Add)                   (None, 128)                  0         ['dense_58[0][0]',
#                                                                      'dense_57[0][0]']
#
#  dense_59 (Dense)            (None, 256)                  33024     ['add[0][0]']
#
#  dense_60 (Dense)            (None, 50)                   12850     ['dense_59[0][0]']
#
# ==================================================================================================
# Total params: 286898 (1.09 MB)
# Trainable params: 286898 (1.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
autoencoder.summary()
# Out:
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  model_14 (Functional)       (None, 50)                286898
#
#  model_17 (Functional)       (None, 32, 32, 3)         550851
#
# =================================================================
# Total params: 837749 (3.20 MB)
# Trainable params: 837749 (3.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Use the best_basic_model as the encoder
encoder = Model(inputs=best_basic_model.input, outputs=best_basic_model.output)

# Display the encoder structure
encoder.summary()
# Out:
# Model: "model_19"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 32, 32, 3)]          0         []
#
#  conv2d_42 (Conv2D)          (None, 32, 32, 32)           896       ['input_15[0][0]']
#
#  max_pooling2d_42 (MaxPooli  (None, 16, 16, 32)           0         ['conv2d_42[0][0]']
#  ng2D)
#
#  conv2d_43 (Conv2D)          (None, 16, 16, 64)           18496     ['max_pooling2d_42[0][0]']
#
#  max_pooling2d_43 (MaxPooli  (None, 8, 8, 64)             0         ['conv2d_43[0][0]']
#  ng2D)
#
#  conv2d_44 (Conv2D)          (None, 8, 8, 128)            73856     ['max_pooling2d_43[0][0]']
#
#  max_pooling2d_44 (MaxPooli  (None, 4, 4, 128)            0         ['conv2d_44[0][0]']
#  ng2D)
#
#  flatten_14 (Flatten)        (None, 2048)                 0         ['max_pooling2d_44[0][0]']
#
#  dense_56 (Dense)            (None, 64)                   131136    ['flatten_14[0][0]']
#
#  dense_58 (Dense)            (None, 128)                  8320      ['dense_56[0][0]']
#
#  dense_57 (Dense)            (None, 128)                  8320      ['dense_56[0][0]']
#
#  add (Add)                   (None, 128)                  0         ['dense_58[0][0]',
#                                                                      'dense_57[0][0]']
#
#  dense_59 (Dense)            (None, 256)                  33024     ['add[0][0]']
#
#  dense_60 (Dense)            (None, 50)                   12850     ['dense_59[0][0]']
#
# ==================================================================================================
# Total params: 286898 (1.09 MB)
# Trainable params: 286898 (1.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
decoder.summary()
# Out:
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 50)]              0
#
#  dense_70 (Dense)            (None, 256)               13056
#
#  dense_71 (Dense)            (None, 128)               32896
#
#  dense_72 (Dense)            (None, 2048)              264192
#
#  reshape (Reshape)           (None, 4, 4, 128)         0
#
#  conv2d_transpose (Conv2DTr  (None, 4, 4, 128)         147584
#  anspose)
#
#  up_sampling2d (UpSampling2  (None, 8, 8, 128)         0
#  D)
#
#  conv2d_transpose_1 (Conv2D  (None, 8, 8, 64)          73792
#  Transpose)
#
#  up_sampling2d_1 (UpSamplin  (None, 16, 16, 64)        0
#  g2D)
#
#  conv2d_transpose_2 (Conv2D  (None, 16, 16, 32)        18464
#  Transpose)
#
#  up_sampling2d_2 (UpSamplin  (None, 32, 32, 32)        0
#  g2D)
#
#  conv2d_51 (Conv2D)          (None, 32, 32, 3)         867
#
# =================================================================
# Total params: 550851 (2.10 MB)
# Trainable params: 550851 (2.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def create_transfer_model(encoder, decoder):
    """
    Creates a transfer model by combining the encoder and decoder.

    Parameters:
    - encoder: The encoder model (outputs latent space of shape (None, 50)).
    - decoder: The decoder model (expects input of shape (None, 50)).

    Returns:
    - The combined transfer model.
    """
    # freeze the encoder and decoder layers
    encoder.trainable = False
    decoder.trainable = False

    # Input for the transfer model
    encoded_input = encoder.input  # Encoder input: (None, 32, 32, 3)

    # Pass input through the encoder to get the latent representation
    latent_output = encoder.output  # Encoder output: (None, 50)

    # Pass the latent representation to the decoder
    decoded_output = decoder(latent_output)  # Decoder output: (None, 32, 32, 3)

    # Combine into a single model
    transfer_model = Model(inputs=encoded_input, outputs=decoded_output)

    return transfer_model

# %%
encoder = Model(inputs=best_basic_model.input, outputs=best_basic_model.output)

# %%
transfer_model = create_transfer_model(encoder, decoder)
transfer_model.compile(optimizer=OPTIMIZER, loss='mse')
transfer_model.summary()
# Out:
# Model: "model_24"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 32, 32, 3)]          0         []
#
#  conv2d_42 (Conv2D)          (None, 32, 32, 32)           896       ['input_15[0][0]']
#
#  max_pooling2d_42 (MaxPooli  (None, 16, 16, 32)           0         ['conv2d_42[0][0]']
#  ng2D)
#  conv2d_43 (Conv2D)          (None, 16, 16, 64)           18496     ['max_pooling2d_42[0][0]']
#
#  max_pooling2d_43 (MaxPooli  (None, 8, 8, 64)             0         ['conv2d_43[0][0]']
#  ng2D)
#
#  conv2d_44 (Conv2D)          (None, 8, 8, 128)            73856     ['max_pooling2d_43[0][0]']
#
#  max_pooling2d_44 (MaxPooli  (None, 4, 4, 128)            0         ['conv2d_44[0][0]']
#  ng2D)
#
#  flatten_14 (Flatten)        (None, 2048)                 0         ['max_pooling2d_44[0][0]']
#
#  dense_56 (Dense)            (None, 64)                   131136    ['flatten_14[0][0]']
#
#  dense_58 (Dense)            (None, 128)                  8320      ['dense_56[0][0]']
#
#  dense_57 (Dense)            (None, 128)                  8320      ['dense_56[0][0]']
#
#  add (Add)                   (None, 128)                  0         ['dense_58[0][0]',
#                                                                      'dense_57[0][0]']
#
#  dense_59 (Dense)            (None, 256)                  33024     ['add[0][0]']
#
#  dense_60 (Dense)            (None, 50)                   12850     ['dense_59[0][0]']
#
#  model_17 (Functional)       (None, 32, 32, 3)            550851    ['dense_60[0][0]']
#
# ==================================================================================================
# Total params: 837749 (3.20 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 837749 (3.20 MB)
# __________________________________________________________________________________________________

# %%
transfer_model_history = transfer_model.fit(train_images_block_2, train_images_block_2, 
                                            batch_size=BATCH_SIZE, 
                                            epochs=EPOCHS, 
                                            validation_split=VALIDATION_SPLIT, 
                                            callbacks=callbacks)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 12s 19ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 0.0010
# Epoch 2/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 0.0010
# Epoch 3/50
# 625/625 [==============================] - 12s 18ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 0.0010
# Epoch 4/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 0.0010
# Epoch 5/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 0.0010
# Epoch 6/50
# 625/625 [==============================] - 12s 19ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 0.0010
# Epoch 7/50
# 625/625 [==============================] - 12s 19ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 1.0000e-04
# Epoch 8/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 1.0000e-04
# Epoch 9/50
# 625/625 [==============================] - 12s 19ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 1.0000e-04
# Epoch 10/50
# 625/625 [==============================] - 12s 19ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 1.0000e-04
# Epoch 11/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 1.0000e-04
# Epoch 12/50
# 625/625 [==============================] - 12s 18ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 1.0000e-05
# Epoch 13/50
# 625/625 [==============================] - 12s 18ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 1.0000e-05
# Epoch 14/50
# 625/625 [==============================] - 12s 19ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 1.0000e-05
# Epoch 15/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 1.0000e-05
# Epoch 16/50
# 625/625 [==============================] - 11s 18ms/step - loss: 0.0125 - val_loss: 0.0144 - lr: 1.0000e-05

# %%
transfer_model.evaluate(test_images_block_2, test_images_block_2)
# save the transfer model
transfer_model.save(MODEL_DIR_PATH+'/basic_transfer_model.keras')
# Out:
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0147

# %%
# display the decoded images
decoded_images_2 = transfer_model.predict(test_images_block_2)

# display the first 10 images
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 4))
for i in range(10):
    # display original
    ax = plt.subplot(2, 10, i + 1)
    plt.imshow(test_images_block_2[i])
    # get the label names from the label encoder
    # ax.set_title(le.inverse_transform([np.argmax(test_labels_block_1[i])]))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, 10, i + 1 + 10)
    plt.imshow(decoded_images_2[i])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()
# Out:
# 157/157 [==============================] - 2s 16ms/step

# %%
# create a new model trained on the block 2 data to compate with the transfer model
block_2_model = create_model(activation='relu', final_activation='softmax')
block_2_model_history = block_2_model.fit(train_images_block_2, train_labels_block_2, 
                                          batch_size=BATCH_SIZE, 
                                          epochs=EPOCHS, 
                                          validation_split=VALIDATION_SPLIT, 
                                          callbacks=callbacks)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 11s 17ms/step - loss: 3.3772 - accuracy: 0.1165 - val_loss: 2.9473 - val_accuracy: 0.1996 - lr: 0.0010
# Epoch 2/50
# 625/625 [==============================] - 10s 17ms/step - loss: 2.7278 - accuracy: 0.2474 - val_loss: 2.6575 - val_accuracy: 0.2840 - lr: 0.0010
# Epoch 3/50
# 625/625 [==============================] - 11s 17ms/step - loss: 2.4302 - accuracy: 0.3205 - val_loss: 2.3988 - val_accuracy: 0.3358 - lr: 0.0010
# Epoch 4/50
# 625/625 [==============================] - 10s 16ms/step - loss: 2.1777 - accuracy: 0.3826 - val_loss: 2.2259 - val_accuracy: 0.3870 - lr: 0.0010
# Epoch 5/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.9875 - accuracy: 0.4300 - val_loss: 2.1795 - val_accuracy: 0.4072 - lr: 0.0010
# Epoch 6/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.8210 - accuracy: 0.4726 - val_loss: 2.1272 - val_accuracy: 0.4212 - lr: 0.0010
# Epoch 7/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.6787 - accuracy: 0.5067 - val_loss: 1.9881 - val_accuracy: 0.4510 - lr: 0.0010
# Epoch 8/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.5466 - accuracy: 0.5429 - val_loss: 2.0358 - val_accuracy: 0.4476 - lr: 0.0010
# Epoch 9/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.4415 - accuracy: 0.5717 - val_loss: 1.9928 - val_accuracy: 0.4628 - lr: 0.0010
# Epoch 10/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.3268 - accuracy: 0.5956 - val_loss: 2.0818 - val_accuracy: 0.4648 - lr: 0.0010
# Epoch 11/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.2251 - accuracy: 0.6263 - val_loss: 2.0871 - val_accuracy: 0.4638 - lr: 0.0010
# Epoch 12/50
# 625/625 [==============================] - 10s 16ms/step - loss: 1.1334 - accuracy: 0.6494 - val_loss: 2.1278 - val_accuracy: 0.4698 - lr: 0.0010
# Epoch 13/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.7931 - accuracy: 0.7592 - val_loss: 2.0851 - val_accuracy: 0.5044 - lr: 1.0000e-04
# Epoch 14/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.7115 - accuracy: 0.7853 - val_loss: 2.1681 - val_accuracy: 0.4986 - lr: 1.0000e-04
# Epoch 15/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.6708 - accuracy: 0.7980 - val_loss: 2.2232 - val_accuracy: 0.4984 - lr: 1.0000e-04
# Epoch 16/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.6393 - accuracy: 0.8069 - val_loss: 2.2681 - val_accuracy: 0.4970 - lr: 1.0000e-04
# Epoch 17/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.6100 - accuracy: 0.8155 - val_loss: 2.3132 - val_accuracy: 0.4964 - lr: 1.0000e-04
# Epoch 18/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5591 - accuracy: 0.8357 - val_loss: 2.3241 - val_accuracy: 0.5004 - lr: 1.0000e-05
# Epoch 19/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5527 - accuracy: 0.8380 - val_loss: 2.3387 - val_accuracy: 0.4996 - lr: 1.0000e-05
# Epoch 20/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.5490 - accuracy: 0.8393 - val_loss: 2.3444 - val_accuracy: 0.5006 - lr: 1.0000e-05
# Epoch 21/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5458 - accuracy: 0.8397 - val_loss: 2.3605 - val_accuracy: 0.4988 - lr: 1.0000e-05
# Epoch 22/50
# 625/625 [==============================] - 11s 17ms/step - loss: 0.5425 - accuracy: 0.8407 - val_loss: 2.3636 - val_accuracy: 0.4988 - lr: 1.0000e-05

# %%
# evaluate the block 2 model
evaluate_model(block_2_model, block_2_model_history.history, test_images_block_2, test_labels_block_2)
# Out:
# 157/157 [==============================] - 1s 8ms/step - loss: 1.9529 - accuracy: 0.4562
# Test loss:  1.952925443649292
# Test accuracy:  0.4562000036239624
# 157/157 [==============================] - 1s 8ms/step
# Confusion matrix:
# [[59  2  0 ...  2  0  0]
#  [ 0 17  3 ...  2  0  3]
#  [ 0  0 77 ...  0  0  0]
#  ...
#  [ 3  0  0 ... 28  1  2]
#  [ 0  0  0 ...  5 33  3]
#  [ 0  0  1 ...  3  1 41]]
# 157/157 [==============================] - 1s 7ms/step
# 0.4562
#               precision    recall  f1-score   support
#
#            0       0.77      0.59      0.67       100
#            1       0.29      0.17      0.21       100
#            2       0.52      0.77      0.62       100
#            3       0.28      0.07      0.11       100
#            4       0.43      0.43      0.43       100
#            5       0.18      0.31      0.23       100
#            6       0.44      0.37      0.40       100
#            7       0.20      0.09      0.12       100
#            8       0.38      0.41      0.39       100
#            9       0.36      0.64      0.46       100
#           10       0.42      0.48      0.45       100
#           11       0.42      0.19      0.26       100
#           12       0.50      0.63      0.56       100
#           13       0.38      0.59      0.46       100
#           14       0.18      0.12      0.14       100
#           15       0.52      0.44      0.48       100
#           16       0.30      0.15      0.20       100
#           17       0.78      0.66      0.71       100
#           18       0.54      0.61      0.58       100
#           19       0.33      0.41      0.36       100
#           20       0.31      0.45      0.37       100
#           21       0.63      0.66      0.65       100
#           22       0.45      0.62      0.52       100
#           23       0.53      0.76      0.63       100
#           24       0.31      0.25      0.28       100
#           25       0.53      0.40      0.46       100
#           26       0.59      0.61      0.60       100
#           27       0.33      0.33      0.33       100
#           28       0.73      0.53      0.61       100
#           29       0.45      0.22      0.30       100
#           30       0.51      0.35      0.42       100
#           31       0.28      0.30      0.29       100
#           32       0.41      0.48      0.44       100
#           33       0.45      0.26      0.33       100
#           34       0.38      0.44      0.41       100
#           35       0.60      0.90      0.72       100
#           36       0.52      0.54      0.53       100
#           37       0.30      0.35      0.33       100
#           38       0.55      0.72      0.63       100
#           39       0.58      0.47      0.52       100
#           40       0.75      0.36      0.49       100
#           41       0.23      0.21      0.22       100
#           42       0.50      0.46      0.48       100
#           43       0.65      0.82      0.72       100
#           44       0.70      0.73      0.71       100
#           45       0.69      0.82      0.75       100
#           46       0.55      0.62      0.58       100
#           47       0.24      0.28      0.26       100
#           48       0.57      0.33      0.42       100
#           49       0.35      0.41      0.38       100
#
#     accuracy                           0.46      5000
#    macro avg       0.46      0.46      0.44      5000
# weighted avg       0.46      0.46      0.44      5000

# %%
# create an decoder model to reconstruct the images based on the new block 2 model
block_2_decoder = create_decoder(input_dim=50, activation='relu', final_activation='sigmoid', loss_function='mse')
block_2_decoder.summary()
# Out:
# Model: "model_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 50)]              0
#
#  dense_90 (Dense)            (None, 256)               13056
#
#  dense_91 (Dense)            (None, 128)               32896
#
#  dense_92 (Dense)            (None, 2048)              264192
#
#  reshape_1 (Reshape)         (None, 4, 4, 128)         0
#
#  conv2d_transpose_3 (Conv2D  (None, 4, 4, 128)         147584
#  Transpose)
#
#  up_sampling2d_3 (UpSamplin  (None, 8, 8, 128)         0
#  g2D)
#
#  conv2d_transpose_4 (Conv2D  (None, 8, 8, 64)          73792
#  Transpose)
#
#  up_sampling2d_4 (UpSamplin  (None, 16, 16, 64)        0
#  g2D)
#
#  conv2d_transpose_5 (Conv2D  (None, 16, 16, 32)        18464
#  Transpose)
#
#  up_sampling2d_5 (UpSamplin  (None, 32, 32, 32)        0
#  g2D)
#
#  conv2d_64 (Conv2D)          (None, 32, 32, 3)         867
#
# =================================================================
# Total params: 550851 (2.10 MB)
# Trainable params: 550851 (2.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Combine encoder and decoder into an autoencoder
encoded_input_2 = block_2_model.input
encoded_output_2 = block_2_model(encoded_input_2)  
decoded_output_2 = decoder(encoded_output_2)  

# Create the model
autoencoder_2 = Model(inputs=encoded_input_2, outputs=decoded_output_2)

# Compile the model
autoencoder_2.compile(optimizer=OPTIMIZER, loss='mse')

# Display the autoencoder model summary
autoencoder_2.summary()
# Out:
# Model: "model_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  model_28 (Functional)       (None, 50)                278578
#
#  model_17 (Functional)       (None, 32, 32, 3)         550851
#
# =================================================================
# Total params: 829429 (3.16 MB)
# Trainable params: 278578 (1.06 MB)
# Non-trainable params: 550851 (2.10 MB)
# _________________________________________________________________

# %%
# train the autoencoder model
autoencoder_2_history = autoencoder_2.fit(train_images_block_2, train_images_block_2, 
                                          batch_size=BATCH_SIZE, 
                                          epochs=EPOCHS, 
                                          validation_split=VALIDATION_SPLIT, 
                                          callbacks=callbacks)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 23s 36ms/step - loss: 0.0459 - val_loss: 0.0409 - lr: 0.0010
# Epoch 2/50
# 625/625 [==============================] - 23s 37ms/step - loss: 0.0398 - val_loss: 0.0397 - lr: 0.0010
# Epoch 3/50
# 625/625 [==============================] - 23s 36ms/step - loss: 0.0390 - val_loss: 0.0392 - lr: 0.0010
# Epoch 4/50
# 625/625 [==============================] - 22s 36ms/step - loss: 0.0386 - val_loss: 0.0389 - lr: 0.0010
# Epoch 5/50
# 625/625 [==============================] - 23s 36ms/step - loss: 0.0383 - val_loss: 0.0387 - lr: 0.0010
# Epoch 6/50
# 625/625 [==============================] - 22s 36ms/step - loss: 0.0381 - val_loss: 0.0386 - lr: 0.0010
# Epoch 7/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0379 - val_loss: 0.0384 - lr: 0.0010
# Epoch 8/50
# 625/625 [==============================] - 22s 34ms/step - loss: 0.0378 - val_loss: 0.0382 - lr: 0.0010
# Epoch 9/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0376 - val_loss: 0.0382 - lr: 0.0010
# Epoch 10/50
# 625/625 [==============================] - 21s 34ms/step - loss: 0.0375 - val_loss: 0.0379 - lr: 0.0010
# Epoch 11/50
# 625/625 [==============================] - 21s 34ms/step - loss: 0.0374 - val_loss: 0.0380 - lr: 0.0010
# Epoch 12/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0373 - val_loss: 0.0379 - lr: 0.0010
# Epoch 13/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0372 - val_loss: 0.0379 - lr: 0.0010
# Epoch 14/50
# 625/625 [==============================] - 21s 34ms/step - loss: 0.0372 - val_loss: 0.0378 - lr: 0.0010
# Epoch 15/50
# 625/625 [==============================] - 22s 34ms/step - loss: 0.0371 - val_loss: 0.0377 - lr: 0.0010
# Epoch 16/50
# 625/625 [==============================] - 21s 34ms/step - loss: 0.0370 - val_loss: 0.0376 - lr: 0.0010
# Epoch 17/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0370 - val_loss: 0.0376 - lr: 0.0010
# Epoch 18/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0369 - val_loss: 0.0376 - lr: 0.0010
# Epoch 19/50
# 625/625 [==============================] - 22s 34ms/step - loss: 0.0369 - val_loss: 0.0377 - lr: 0.0010
# Epoch 20/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0369 - val_loss: 0.0376 - lr: 0.0010
# Epoch 21/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0368 - val_loss: 0.0376 - lr: 0.0010
# Epoch 22/50
# 625/625 [==============================] - 21s 34ms/step - loss: 0.0365 - val_loss: 0.0373 - lr: 1.0000e-04
# Epoch 23/50
# 625/625 [==============================] - 21s 33ms/step - loss: 0.0364 - val_loss: 0.0373 - lr: 1.0000e-04
# Epoch 24/50
# 625/625 [==============================] - 21s 33ms/step - loss: 0.0364 - val_loss: 0.0373 - lr: 1.0000e-04
# Epoch 25/50
# 625/625 [==============================] - 21s 33ms/step - loss: 0.0364 - val_loss: 0.0373 - lr: 1.0000e-04
# Epoch 26/50
# 625/625 [==============================] - 21s 34ms/step - loss: 0.0364 - val_loss: 0.0373 - lr: 1.0000e-04
# Epoch 27/50
# 625/625 [==============================] - 21s 34ms/step - loss: 0.0364 - val_loss: 0.0373 - lr: 1.0000e-04
# Epoch 28/50
# 625/625 [==============================] - 21s 34ms/step - loss: 0.0363 - val_loss: 0.0373 - lr: 1.0000e-05
# Epoch 29/50
# 625/625 [==============================] - 21s 34ms/step - loss: 0.0363 - val_loss: 0.0373 - lr: 1.0000e-05
# Epoch 30/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0363 - val_loss: 0.0373 - lr: 1.0000e-05
# Epoch 31/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0363 - val_loss: 0.0373 - lr: 1.0000e-05
# Epoch 32/50
# 625/625 [==============================] - 23s 36ms/step - loss: 0.0363 - val_loss: 0.0373 - lr: 1.0000e-05
# Epoch 33/50
# 625/625 [==============================] - 23s 37ms/step - loss: 0.0363 - val_loss: 0.0373 - lr: 1.0000e-06
# Epoch 34/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0363 - val_loss: 0.0373 - lr: 1.0000e-06
# Epoch 35/50
# 625/625 [==============================] - 22s 35ms/step - loss: 0.0363 - val_loss: 0.0373 - lr: 1.0000e-06
# 157/157 [==============================] - 2s 14ms/step

# %%
# display the decoded images
decoded_images_2 = autoencoder_2.predict(test_images_block_2)

# display the first 10 images
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 4))
for i in range(10):
    # display original
    ax = plt.subplot(2, 10, i + 1)
    plt.imshow(test_images_block_2[i])
    # get the label names from the label encoder
    # ax.set_title(le.inverse_transform([np.argmax(test_labels_block_1[i])]))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, 10, i + 1 + 10)
    plt.imshow(decoded_images_2[i])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# Out:
# 157/157 [==============================] - 2s 15ms/step

# %%
autoencoder_2.evaluate(test_images_block_2, test_images_block_2)
# Out:
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0376
# 0.03759882599115372

# %%
# save the autoencoder model
autoencoder_2.save(MODEL_DIR_PATH+'/block_2_autoencoder_model.keras')
