# %% [markdown]
# ### Part 2: Image Processing and Transfer Learning - 50%
# In part 2 of the assignment, we switch from text processing to image processing to explore
# another set of model tasks. Again, you are asked to follow a set of instructions below and report
# on your findings.
#
# For this assignment we will make use of the CIFAR-100 dataset of images.
# - Rather than using all images, you are asked to randomly split CIFAR into two subsets of 50 classes each.
# - Your first task is to make these subsets and save these subsets to disk for use later.
# - Make sure to randomly select these classes (don’t just take the first 50).
# - Also make sure to account for training, validation or test as appropriate.
# - We will refer to the first set of data as Block 1 and the second set of 50 classes as Block 2.
#
# As with Part 1, the set of tasks below do not build on each other and can in some ways be
# considered independent.

# %%
import numpy as np
import pickle
import os

from tensorflow.keras.datasets import cifar100

(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# normalise the pixel values to be between 0 and 1
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

# Load the CIFAR-100 data
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# Save the CIFAR-100 data
def save_pickle(data, file):
    with open(file, 'wb') as fo:
        pickle.dump(data, fo)

# %%
# display the first 10 images
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 4))
for i in range(5):
    # display original
    ax = plt.subplot(2, 5, i + 1)
    plt.imshow(test_images[i])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# ### Task 1: Load the CIFAR-100 dataset and split it into two sets of 50 classes each.

# %% [markdown]
# #### Randomly select 50 classes for Block 1 and 50 classes for Block 2.

# %%
# The CIFAR-100 dataset has 100 classes
num_classes = 100
np.random.seed(42)
classes = np.arange(num_classes)
np.random.shuffle(classes)

# %%
# Split the class indices into two subsets of 50 classes each
block_1_classes = classes[:50]
block_2_classes = classes[50:]

# %% [markdown]
# #### Filter the dataset to only include the selected classes for each block.

# %%
def filter_by_classes(images, labels, class_subset):
    """
    Filters images and labels by a subset of classes.

    Args:
        images (numpy.ndarray): Array of images.
        labels (numpy.ndarray): Array of labels corresponding to the images.
        class_subset (list or numpy.ndarray): List or array of class labels to filter by.

    Returns:
        tuple: A tuple containing:
            - filtered_images (numpy.ndarray): Array of images filtered by the specified classes.
            - filtered_labels (numpy.ndarray): Array of labels filtered by the specified classes.
    """
    indices = np.isin(labels, class_subset)
    filtered_images = images[indices.flatten()]
    filtered_labels = labels[indices.flatten()]
    return filtered_images, filtered_labels

# %%
def remap_labels(labels, class_subset):
    """
    Remaps the given labels to a new set of labels based on a subset of classes.

    Parameters:
    labels (array-like): The original labels to be remapped.
    class_subset (array-like): The subset of classes to which the labels should be remapped.

    Returns:
    numpy.ndarray: An array of remapped labels.
    """
    class_mapping = {original: new for new, original in enumerate(class_subset)}
    return np.array([class_mapping[label] for label in labels])

# %%
# Create subsets for train and test data
train_images_block_1, train_labels_block_1 = filter_by_classes(train_images, train_labels, block_1_classes)
train_images_block_2, train_labels_block_2 = filter_by_classes(train_images, train_labels, block_2_classes)
test_images_block_1, test_labels_block_1 = filter_by_classes(test_images, test_labels, block_1_classes)
test_images_block_2, test_labels_block_2 = filter_by_classes(test_images, test_labels, block_2_classes)

# print the shape of the train and test data
print(train_images_block_1.shape)
print(train_labels_block_1.shape)
print(train_images_block_2.shape)
print(train_labels_block_2.shape)
# Out:
# (25000, 32, 32, 3)
# (25000, 1)
# (25000, 32, 32, 3)
# (25000, 1)

# %%
train_labels_block_1 = remap_labels(train_labels_block_1.flatten().tolist(), block_1_classes)
test_labels_block_1 = remap_labels(test_labels_block_1.flatten().tolist(), block_1_classes)
train_labels_block_2 = remap_labels(train_labels_block_2.flatten().tolist(), block_2_classes)
test_labels_block_2 = remap_labels(test_labels_block_2.flatten().tolist(), block_2_classes)

# %% [markdown]
# #### Save the images for each block to disk for use in the next task.

# %%
def save_to_disk(data, labels, path):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    with open(path, 'wb') as f:
        pickle.dump((data, labels), f)

save_to_disk(train_images_block_1, train_labels_block_1, 'data/CIFAR-100/train_dir/block_1_train.pkl')
save_to_disk(test_images_block_1, test_labels_block_1, 'data/CIFAR-100/test_dir/block_1_test.pkl')

save_to_disk(train_images_block_2, train_labels_block_2, 'data/CIFAR-100/train_dir/block_2_train.pkl')
save_to_disk(test_images_block_2, test_labels_block_2, 'data/CIFAR-100/test_dir/block_2_test.pkl')

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
train_labels_block_1 = le.fit_transform(train_labels_block_1)
test_labels_block_1 = le.transform(test_labels_block_1)

train_labels_block_1 = to_categorical(train_labels_block_1, num_classes=50)
test_labels_block_1 = to_categorical(test_labels_block_1, num_classes=50)

# %%
print("Train data shape: ", train_images_block_1.shape)
print("Train labels shape: ", train_labels_block_1.shape)
# Out:
# Train data shape:  (25000, 32, 32, 3)
# Train labels shape:  (25000, 50)

# %% [markdown]
# ### Basic Modelling: For Block 1 images:
# 1. Build a home-built network with 5 hidden layers of your choosing to classify the Block 1 images.
# 2. Report on relevant metrics and losses.
# 3. Investigate the use of different activation functions in this network.
# 4. Investigate the use of different losses in the network and the use of softmax vs logistic activation functions in the final layer.
# 5. Investigate the use of skip connections in network design.
# 6. Save the best performing model for the demo notebook and use later.

# %% [markdown]
# ### Constants

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
"""
This script sets up two Keras callbacks for training a deep learning model: EarlyStopping and ReduceLROnPlateau.

Callbacks:
    - EarlyStopping: Monitors the training process and stops training when a monitored metric has stopped improving.
        Parameters:
            min_delta (float): Minimum change in the monitored quantity to qualify as an improvement.
            patience (int): Number of epochs with no improvement after which training will be stopped.
            restore_best_weights (bool): Whether to restore model weights from the epoch with the best value of the monitored quantity.

    - ReduceLROnPlateau: Reduces the learning rate when a monitored metric has stopped improving.
        Parameters:
            monitor (str): Quantity to be monitored.
            factor (float): Factor by which the learning rate will be reduced. new_lr = lr * factor.
            patience (int): Number of epochs with no improvement after which learning rate will be reduced.
            min_lr (float): Lower bound on the learning rate.

The callbacks are stored in a list named `callbacks` and can be passed to the `fit` method of a Keras model.
"""

early_stopping = EarlyStopping(
    min_delta=0.001, # minimum amount of change to count as an improvement
    patience=15, # how many epochs to wait before stopping
    restore_best_weights=True,
)

reduceOnPlateau = ReduceLROnPlateau(
    monitor='val_loss', # value being monitored for improvement
    factor=0.1, # factor by which the learning rate will be reduced
    patience=5, # number of epochs with no improvement after which learning rate will be reduced
    min_lr=1e-6, # lower bound on the learning rate
)

callbacks = [early_stopping, reduceOnPlateau]

# %%
"""
Constants used to maintain consistency across initial training.

Attributes:
    UNITS (int): Number of units in the neural network layers.
    EMBEDDING_DIM (int): Dimension of the embedding layer.
    OUTPUT_DIM (int): Dimension of the output layer.
    BATCH_SIZE (int): Number of samples per gradient update.
    EPOCHS (int): Number of epochs to train the model.
    DROPOUT_RATE (float): Fraction of the input units to drop.
    DENSE_ACTIVATION (str): Activation function to use in dense layers.
    OPTIMIZER (str): Optimizer to use for training the model.
    VALIDATION_SPLIT (float): Fraction of the training data to be used as validation data.
"""
UNITS=64
EMBEDDING_DIM=100
OUTPUT_DIM=10
BATCH_SIZE=32
EPOCHS=30
DROPOUT_RATE=0.5
DENSE_ACTIVATION='relu'
OPTIMIZER='adam'
VALIDATION_SPLIT=0.2

# %%
# Plotting helper functions
def plot_training_results(history, metric='accuracy'):
    plt.figure(figsize=(10, 6))
    plt.plot(history[metric], label='Training ' + metric)
    plt.plot(history['val_'+metric], label='Validation ' + metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.title('Training and Validation ' + metric)
    plt.legend()
    plt.show()

# %%
# create an evaluation function
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

def evaluate_model(model, 
                   model_history, 
                   X_test,
                   y_test,
                   label_encoder=le):
    loss, acc = model.evaluate(X_test, y_test)
    print('Test loss: ', loss)
    print('Test accuracy: ', acc)

  
    y_pred = model.predict(X_test)
    y_pred = np.argmax(y_pred, axis=1)
    y_true = np.argmax(y_test, axis=1)
    print('Confusion matrix:')
    print(confusion_matrix(y_true, y_pred))

    # make predictions
    y_pred = model.predict(X_test)

    # convert the predictions to the target variable
    y_pred = label_encoder.inverse_transform(y_pred.argmax(axis=1))

    # convert the test target variable to the original values
    y_test = label_encoder.inverse_transform(y_test.argmax(axis=1))

    print(accuracy_score(y_test, y_pred))
        
    # Print classification report
    print(classification_report(y_test, y_pred))
    
    # Plot results
    plot_training_results(model_history)
    plot_training_results(model_history, metric='loss')

# %%
from tensorflow.keras.layers import Input, Dense, Flatten, Rescaling
from tensorflow.keras.models import Model
from tensorflow.keras.layers import add

def create_model(output_dim=50,
                activation='relu',
                optimizer='adam',
                final_activation='softmax',
                loss_function='categorical_crossentropy',
                use_skip=False):
    inputs = Input(shape=(32, 32, 3))
    input_layer = Flatten()(inputs)
    
    # First hidden layer
    dense_one = Dense(512, activation=activation)(input_layer)
    # Second hidden layer
    dense_two = Dense(256, activation=activation)(dense_one)
    
    # Optional skip connection
    if use_skip:
        # Match the dimensions before adding
        dense_one_resized = Dense(256, activation=activation)(dense_one)
        dense_two = add([dense_one_resized, dense_two])

    # Third hidden layer
    dense_three = Dense(128, activation=activation)(dense_two)
    # Fourth hidden layer
    dense_four = Dense(64, activation=activation)(dense_three)
    # Fifth hidden layer
    dense_five = Dense(32, activation=activation)(dense_four)
    # Output layer
    outputs = Dense(output_dim, activation=final_activation)(dense_five)

    model = Model(inputs, outputs)

    # Compile the model
    model.compile(optimizer=optimizer,
                loss=loss_function,
                metrics=['accuracy'])
    return model

# %%
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, Dense, Flatten, Rescaling

# def create_model(output_dim=50,
#                  activation='relu',
#                  optimizer='adam',
#                  final_activation='softmax',
#                  loss_function='categorical_crossentropy',
#                  use_skip=False):
#     inputs = Input(shape=(32, 32, 3))

#     # # Rescaling layer
#     # rescaling_layer = Rescaling(1./255)(inputs)

#     # Encoder layers
#     conv1 = Conv2D(32, (3, 3), activation=activation, padding='same')(inputs)
#     pool1 = MaxPooling2D((2, 2))(conv1)

#     conv2 = Conv2D(64, (3, 3), activation=activation, padding='same')(pool1)
#     pool2 = MaxPooling2D((2, 2))(conv2)

#     conv3 = Conv2D(128, (3, 3), activation=activation, padding='same')(pool2)
#     pool3 = MaxPooling2D((2, 2))(conv3)

#     # Flatten layer
#     flat = Flatten()(pool3)

#     # Dense layers for encoding
#     dense_one = Dense(64, activation=activation)(flat)
#     dense_two = Dense(128, activation=activation)(dense_one)

#     if use_skip:
#         dense_one_resized = Dense(128, activation=activation)(dense_one)
#         dense_two = add([dense_one_resized, dense_two])

#     dense_three = Dense(256, activation=activation)(dense_two)

#     # Output layer
#     final_output = Dense(output_dim, activation=final_activation)(dense_three)

#     model = Model(inputs, final_output)

#     model.compile(optimizer=optimizer,
#                   loss=loss_function,
#                   metrics=['accuracy'])

#     return model

# %% [markdown]
# #### Basic Modelling: For Block 1 images:
# 1. Build a home-built network with 5 hidden layers of your choosing to classify the Block 1 images.

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

# create the basic model
basic_model = create_model()
basic_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 512)               1573376
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 50)                1650
#
# =================================================================
# Total params: 1749586 (6.67 MB)
# Trainable params: 1749586 (6.67 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Check the shapes of train_data_block_1 and train_labels_block_1
print("Shape of train_data_block_1:", train_images_block_1.shape)
print("Shape of train_labels_block_1:", train_labels_block_1.shape)

# train the model
model_history = basic_model.fit(train_images_block_1, train_labels_block_1, 
                                batch_size=BATCH_SIZE, 
                                epochs=EPOCHS, 
                                validation_split=VALIDATION_SPLIT, 
                                callbacks=callbacks)
# Out:
# Shape of train_data_block_1: (25000, 32, 32, 3)
# Shape of train_labels_block_1: (25000, 50)
# Epoch 1/30
# 625/625 [==============================] - 3s 4ms/step - loss: 3.7040 - accuracy: 0.0524 - val_loss: 3.4878 - val_accuracy: 0.0816 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 3s 4ms/step - loss: 3.4105 - accuracy: 0.0962 - val_loss: 3.3782 - val_accuracy: 0.1076 - lr: 0.0010
# Epoch 3/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.2994 - accuracy: 0.1185 - val_loss: 3.2872 - val_accuracy: 0.1260 - lr: 0.0010
# Epoch 4/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.2097 - accuracy: 0.1439 - val_loss: 3.1770 - val_accuracy: 0.1590 - lr: 0.0010
# Epoch 5/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.1275 - accuracy: 0.1659 - val_loss: 3.1684 - val_accuracy: 0.1524 - lr: 0.0010
# Epoch 6/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.0535 - accuracy: 0.1786 - val_loss: 3.0825 - val_accuracy: 0.1844 - lr: 0.0010
# Epoch 7/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.0053 - accuracy: 0.1902 - val_loss: 3.0741 - val_accuracy: 0.1840 - lr: 0.0010
# Epoch 8/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.9507 - accuracy: 0.2058 - val_loss: 3.0466 - val_accuracy: 0.1870 - lr: 0.0010
# Epoch 9/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.9066 - accuracy: 0.2177 - val_loss: 3.0409 - val_accuracy: 0.1860 - lr: 0.0010
# Epoch 10/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.8705 - accuracy: 0.2240 - val_loss: 2.9678 - val_accuracy: 0.2038 - lr: 0.0010
# Epoch 11/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.8308 - accuracy: 0.2343 - val_loss: 3.0467 - val_accuracy: 0.1902 - lr: 0.0010
# Epoch 12/30
# 625/625 [==============================] - 3s 4ms/step - loss: 2.7982 - accuracy: 0.2384 - val_loss: 3.0078 - val_accuracy: 0.1988 - lr: 0.0010
# Epoch 13/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.7623 - accuracy: 0.2502 - val_loss: 2.9520 - val_accuracy: 0.2122 - lr: 0.0010
# Epoch 14/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.7236 - accuracy: 0.2567 - val_loss: 2.9067 - val_accuracy: 0.2188 - lr: 0.0010
# Epoch 15/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.6881 - accuracy: 0.2618 - val_loss: 2.9542 - val_accuracy: 0.2140 - lr: 0.0010
# Epoch 16/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.6637 - accuracy: 0.2693 - val_loss: 2.8839 - val_accuracy: 0.2320 - lr: 0.0010
# Epoch 17/30
# 625/625 [==============================] - 3s 4ms/step - loss: 2.6238 - accuracy: 0.2804 - val_loss: 2.9189 - val_accuracy: 0.2252 - lr: 0.0010
# Epoch 18/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.5929 - accuracy: 0.2894 - val_loss: 2.9086 - val_accuracy: 0.2316 - lr: 0.0010
# Epoch 19/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.5693 - accuracy: 0.2894 - val_loss: 2.9375 - val_accuracy: 0.2234 - lr: 0.0010
# Epoch 20/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.5275 - accuracy: 0.2992 - val_loss: 2.9284 - val_accuracy: 0.2320 - lr: 0.0010
# Epoch 21/30
# 625/625 [==============================] - 3s 4ms/step - loss: 2.4991 - accuracy: 0.3063 - val_loss: 2.9888 - val_accuracy: 0.2262 - lr: 0.0010
# Epoch 22/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.3056 - accuracy: 0.3543 - val_loss: 2.8735 - val_accuracy: 0.2524 - lr: 1.0000e-04
# Epoch 23/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.2539 - accuracy: 0.3635 - val_loss: 2.8820 - val_accuracy: 0.2526 - lr: 1.0000e-04
# Epoch 24/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.2326 - accuracy: 0.3722 - val_loss: 2.8911 - val_accuracy: 0.2594 - lr: 1.0000e-04
# Epoch 25/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.2174 - accuracy: 0.3765 - val_loss: 2.8944 - val_accuracy: 0.2548 - lr: 1.0000e-04
# Epoch 26/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.2026 - accuracy: 0.3794 - val_loss: 2.9024 - val_accuracy: 0.2524 - lr: 1.0000e-04
# Epoch 27/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.1899 - accuracy: 0.3817 - val_loss: 2.9142 - val_accuracy: 0.2532 - lr: 1.0000e-04
# Epoch 28/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.1567 - accuracy: 0.3925 - val_loss: 2.9086 - val_accuracy: 0.2566 - lr: 1.0000e-05
# Epoch 29/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.1519 - accuracy: 0.3933 - val_loss: 2.9134 - val_accuracy: 0.2558 - lr: 1.0000e-05
# Epoch 30/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.1501 - accuracy: 0.3933 - val_loss: 2.9126 - val_accuracy: 0.2544 - lr: 1.0000e-05

# %% [markdown]
# #### 2. Report on relevant metrics and losses.

# %%
# evaluate the model
evaluate_model(basic_model, model_history.history, test_images_block_1, test_labels_block_1)
# Out:
# 157/157 [==============================] - 0s 2ms/step - loss: 2.9210 - accuracy: 0.2626
# Test loss:  2.9209604263305664
# Test accuracy:  0.26260000467300415
# 157/157 [==============================] - 0s 1ms/step
# Confusion matrix:
# [[27 15  4 ...  2  5  0]
#  [ 1 71  3 ...  1  3  0]
#  [ 4  2 48 ...  0 13  0]
#  ...
#  [ 0  2  0 ... 14  1  7]
#  [ 6  9 10 ...  1 44  1]
#  [ 0  2  0 ...  2  0 15]]
# 157/157 [==============================] - 0s 1ms/step
# 0.2626
#               precision    recall  f1-score   support
#
#            0       0.40      0.27      0.32       100
#            1       0.48      0.71      0.57       100
#            2       0.43      0.48      0.45       100
#            3       0.20      0.14      0.16       100
#            4       0.13      0.18      0.15       100
#            5       0.20      0.26      0.23       100
#            6       0.25      0.26      0.26       100
#            7       0.14      0.04      0.06       100
#            8       0.20      0.13      0.16       100
#            9       0.42      0.47      0.45       100
#           10       0.29      0.27      0.28       100
#           11       0.37      0.47      0.42       100
#           12       0.41      0.42      0.41       100
#           13       0.27      0.30      0.28       100
#           14       0.19      0.25      0.22       100
#           15       0.15      0.19      0.17       100
#           16       0.36      0.41      0.38       100
#           17       0.14      0.11      0.12       100
#           18       0.26      0.31      0.29       100
#           19       0.20      0.25      0.22       100
#           20       0.10      0.05      0.07       100
#           21       0.10      0.06      0.07       100
#           22       0.12      0.13      0.13       100
#           23       0.14      0.18      0.16       100
#           24       0.32      0.36      0.34       100
#           25       0.17      0.12      0.14       100
#           26       0.36      0.28      0.32       100
#           27       0.30      0.29      0.30       100
#           28       0.43      0.27      0.33       100
#           29       0.13      0.08      0.10       100
#           30       0.20      0.12      0.15       100
#           31       0.48      0.50      0.49       100
#           32       0.35      0.43      0.39       100
#           33       0.35      0.42      0.38       100
#           34       0.19      0.14      0.16       100
#           35       0.21      0.38      0.27       100
#           36       0.10      0.16      0.12       100
#           37       0.18      0.14      0.16       100
#           38       0.21      0.23      0.22       100
#           39       0.23      0.20      0.21       100
#           40       0.42      0.44      0.43       100
#           41       0.17      0.22      0.19       100
#           42       0.36      0.45      0.40       100
#           43       0.38      0.39      0.38       100
#           44       0.08      0.10      0.09       100
#           45       0.23      0.16      0.19       100
#           46       0.21      0.18      0.19       100
#           47       0.23      0.14      0.17       100
#           48       0.49      0.44      0.47       100
#           49       0.19      0.15      0.17       100
#
#     accuracy                           0.26      5000
#    macro avg       0.26      0.26      0.26      5000
# weighted avg       0.26      0.26      0.26      5000

# %% [markdown]
# #### 3. Investigate the use of different activation functions in this network.

# %%
# create a definition to loop through the different models
def run_activation_experiment(activations, 
                              model, 
                              train_images, 
                              train_labels, 
                              test_images, 
                              test_labels, 
                              callbacks):

    # create a list to hold investigation results
    results = []
    # loop through the activation functions
    for activation in activations:
        print(f'Running experiment with activation: {activation}')
        # create the model
        model = create_model(activation=activation)
        # train the model
        model_history = model.fit(train_images, train_labels, 
                                    batch_size=BATCH_SIZE, 
                                    epochs=EPOCHS, 
                                    validation_split=VALIDATION_SPLIT, 
                                    callbacks=callbacks)

        # evaluate the model
        loss, accuracy = model.evaluate(test_images, test_labels)
        results.append({
            'model': model,
            'history': model_history.history,
            'experiment_variable': activation,
            'loss': loss,
            'accuracy': accuracy
        })
    results = sorted(results, key=lambda x: x['accuracy'], reverse=True)
    return results

# %%
# create a list of activation functions
activations = ['relu','leaky_relu','tanh', 'sigmoid', 'softmax']

activation_results = run_activation_experiment(activations,
                                                basic_model,
                                                train_images_block_1,
                                                train_labels_block_1,
                                                test_images_block_1,
                                                test_labels_block_1,
                                                callbacks)

# print the top result
print(activation_results[0])
# Out:
# Running experiment with activation: relu
# Epoch 1/30
# 625/625 [==============================] - 3s 4ms/step - loss: 3.6632 - accuracy: 0.0607 - val_loss: 3.4480 - val_accuracy: 0.0972 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3
_images_block_1, test_labels_block_1)
# Out:
# 157/157 [==============================] - 0s 2ms/step - loss: 2.9114 - accuracy: 0.2918
# Test loss:  2.911419630050659
# Test accuracy:  0.29179999232292175
# 157/157 [==============================] - 0s 2ms/step
# Confusion matrix:
# [[20 19  5 ...  2  4  0]
#  [ 6 65  2 ...  1  5  2]
#  [ 3  1 52 ...  1 10  0]
#  ...
#  [ 2  4  0 ... 16  2  1]
#  [ 6  9 15 ...  2 43  1]
#  [ 1  0  0 ...  2  2 23]]
# 157/157 [==============================] - 0s 1ms/step
# 0.2918
#               precision    recall  f1-score   support
#
#            0       0.23      0.20      0.21       100
#            1       0.48      0.65      0.55       100
#            2       0.44      0.52      0.48       100
#            3       0.24      0.15      0.18       100
#            4       0.18      0.23      0.20       100
#            5       0.25      0.33      0.29       100
#            6       0.26      0.28      0.27       100
#            7       0.11      0.10      0.11       100
#            8       0.19      0.14      0.16       100
#            9       0.51      0.48      0.49       100
#           10       0.29      0.29      0.29       100
#           11       0.33      0.42      0.37       100
#           12       0.40      0.40      0.40       100
#           13       0.32      0.35      0.33       100
#           14       0.28      0.31      0.29       100
#           15       0.26      0.25      0.25       100
#           16       0.44      0.51      0.47       100
#           17       0.13      0.11      0.12       100
#           18       0.39      0.33      0.36       100
#           19       0.27      0.31      0.29       100
#           20       0.11      0.05      0.07       100
#           21       0.15      0.15      0.15       100
#           22       0.18      0.19      0.18       100
#           23       0.13      0.15      0.14       100
#           24       0.39      0.46      0.42       100
#           25       0.21      0.20      0.20       100
#           26       0.25      0.24      0.24       100
#           27       0.35      0.31      0.33       100
#           28       0.36      0.31      0.34       100
#           29       0.14      0.10      0.12       100
#           30       0.23      0.16      0.19       100
#           31       0.49      0.50      0.49       100
#           32       0.39      0.52      0.45       100
#           33       0.42      0.42      0.42       100
#           34       0.21      0.15      0.17       100
#           35       0.27      0.39      0.32       100
#           36       0.11      0.13      0.12       100
#           37       0.21      0.16      0.18       100
#           38       0.23      0.22      0.22       100
#           39       0.29      0.26      0.27       100
#           40       0.44      0.52      0.48       100
#           41       0.27      0.35      0.31       100
#           42       0.37      0.49      0.42       100
#           43       0.38      0.38      0.38       100
#           44       0.14      0.14      0.14       100
#           45       0.28      0.21      0.24       100
#           46       0.25      0.25      0.25       100
#           47       0.18      0.16      0.17       100
#           48       0.48      0.43      0.46       100
#           49       0.32      0.23      0.27       100
#
#     accuracy                           0.29      5000
#    macro avg       0.28      0.29      0.29      5000
# weighted avg       0.28      0.29      0.29      5000

# %% [markdown]
# #### 5. Investigate the use of different losses in the network and the use of softmax vs logistic activation functions in the final layer.

# %% [markdown]
# ##### 5a. Investigate different loss functions

# %%
def run_loss_function_experiment(loss_functions, 
                                model, 
                                train_images, 
                                train_labels, 
                                test_images, 
                                test_labels, 
                                callbacks):
    results = []
    for loss_function in loss_functions:
        print(f'Running experiment with loss function: {loss_function}')
        model = create_model(loss_function=loss_function)
        model_history = model.fit(train_images, train_labels, 
                                  batch_size=BATCH_SIZE, 
                                  epochs=EPOCHS, 
                                  validation_split=VALIDATION_SPLIT, 
                                  callbacks=callbacks)
        loss, accuracy = model.evaluate(test_images, test_labels)
        results.append({
            'model': model,
            'history': model_history.history,
            'experiment_variable': loss_function,
            'loss': loss,
            'accuracy': accuracy
        })
    results = sorted(results, key=lambda x: x['accuracy'], reverse=True)
    return results

# %%
# loss functions suitable for multi-class classification
from tensorflow.keras.losses import KLDivergence

loss_functions = [KLDivergence(),'categorical_crossentropy']

# run the loss function experiment
loss_function_results = run_loss_function_experiment(loss_functions,
                                                    basic_model,
                                                    train_images_block_1,
                                                    train_labels_block_1,
                                                    test_images_block_1,
                                                    test_labels_block_1,
                                                    callbacks)

# print the top result
print(loss_function_results[0])
# Out:
# Running experiment with loss function: <keras.src.losses.KLDivergence object at 0x3c8f39390>
# Epoch 1/30
# 625/625 [==============================] - 3s 4ms/step - loss: 3.7558 - accuracy: 0.0441 - val_loss: 3.5148 - val_accuracy: 0.0748 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.4524 - accuracy: 0.0851 - val_loss: 3.3953 - val_accuracy: 0.0928 - lr: 0.0010
# Epoch 3/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.3370 - accuracy: 0.1089 - val_loss: 3.3419 - val_accuracy: 0.1202 - lr: 0.0010
# Epoch 4/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.2330 - accuracy: 0.1357 - val_loss: 3.2246 - val_accuracy: 0.1344 - lr: 0.0010
# Epoch 5/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.1474 - accuracy: 0.1586 - val_loss: 3.1915 - val_accuracy: 0.1548 - lr: 0.0010
# Epoch 6/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.0705 - accuracy: 0.1722 - val_loss: 3.0716 - val_accuracy: 0.1852 - lr: 0.0010
# Epoch 7/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.0127 - accuracy: 0.1890 - val_loss: 3.0266 - val_accuracy: 0.1936 - lr: 0.0010
# Epoch 8/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.9544 - accuracy: 0.2025 - val_loss: 3.0375 - val_accuracy: 0.1892 - lr: 0.0010
# Epoch 9/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.9152 - accuracy: 0.2127 - val_loss: 2.9852 - val_accuracy: 0.2028 - lr: 0.0010
# Epoch 10/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.8757 - accuracy: 0.2171 - val_loss: 2.9848 - val_accuracy: 0.1986 - lr: 0.0010
# Epoch 11/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.8311 - accuracy: 0.2304 - val_loss: 2.9931 - val_accuracy: 0.2004 - lr: 0.0010
# Epoch 12/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.8054 - accuracy: 0.2374 - val_loss: 3.0161 - val_accuracy: 0.2040 - lr: 0.0010
# Epoch 13/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.7730 - accuracy: 0.2449 - val_loss: 2.9463 - val_accuracy: 0.2156 - lr: 0.0010
# Epoch 14/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.7292 - accuracy: 0.2515 - val_loss: 2.8976 - val_accuracy: 0.2308 - lr: 0.0010
# Epoch 15/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.6941 - accuracy: 0.2614 - val_loss: 2.9387 - val_accuracy: 0.2222 - lr: 0.0010
# Epoch 16/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.6691 - accuracy: 0.2685 - val_loss: 2.9663 - val_accuracy: 0.2226 - lr: 0.0010
# Epoch 17/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.6354 - accuracy: 0.2718 - val_loss: 2.9487 - val_accuracy: 0.2290 - lr: 0.0010
# Epoch 18/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.5995 - accuracy: 0.2851 - val_loss: 2.9178 - val_accuracy: 0.2320 - lr: 0.0010
# Epoch 19/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.5635 - accuracy: 0.2903 - val_loss: 2.9073 - val_accuracy: 0.2398 - lr: 0.0010
# Epoch 20/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.3719 - accuracy: 0.3394 - val_loss: 2.8751 - val_accuracy: 0.2498 - lr: 1.0000e-04
# Epoch 21/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2
loss': [3.514787435531616, 3.3952901363372803, 3.3418684005737305, 3.224606990814209, 3.1914610862731934, 3.071641206741333, 3.026636838912964, 3.0374526977539062, 2.9851512908935547, 2.9847962856292725, 2.993093252182007, 3.0161426067352295, 2.9463155269622803, 2.897555112838745, 2.9387083053588867, 2.9663002490997314, 2.9486911296844482, 2.9177706241607666, 2.9072558879852295, 2.8750789165496826, 2.8848557472229004, 2.884783983230591, 2.89819073677063, 2.901841878890991, 2.9095370769500732, 2.9022793769836426, 2.9044063091278076, 2.905264377593994, 2.9065098762512207, 2.907355308532715], 'val_accuracy': [0.07479999959468842, 0.09279999881982803, 0.12020000070333481, 0.13439999520778656, 0.15479999780654907, 0.18520000576972961, 0.19359999895095825, 0.1891999989748001, 0.20280000567436218, 0.19859999418258667, 0.2003999948501587, 0.20399999618530273, 0.21559999883174896, 0.23080000281333923, 0.22220000624656677, 0.22259999811649323, 0.2290000021457672, 0.23199999332427979, 0.23980000615119934, 0.24979999661445618, 0.25220000743865967, 0.2513999938964844, 0.25040000677108765, 0.24660000205039978, 0.24860000610351562, 0.25060001015663147, 0.25200000405311584, 0.2524000108242035, 0.2513999938964844, 0.2524000108242035], 'lr': [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.000100000005, 0.000100000005, 0.000100000005, 0.000100000005, 0.000100000005, 0.000100000005, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05, 1.0000001e-05]}, 'experiment_variable': <keras.src.losses.KLDivergence object at 0x3c8f39390>, 'loss': 2.928403615951538, 'accuracy': 0.2549999952316284}

# %%
# select the best model
best_loss_function_model = loss_function_results[0]['model']

# set a variable to hold the best loss function
best_loss_function = loss_function_results[0]['experiment_variable']

# print the best loss function
print(f'Best loss function: {best_loss_function}')

# evaluate the best model
evaluate_model(best_loss_function_model, loss_function_results[0]['history'], test_images_block_1, test_labels_block_1)
# Out:
# Best loss function: <keras.src.losses.KLDivergence object at 0x3c8f39390>
# 157/157 [==============================] - 0s 2ms/step - loss: 2.9284 - accuracy: 0.2550
# Test loss:  2.928403615951538
# Test accuracy:  0.2549999952316284
# 157/157 [==============================] - 0s 1ms/step
# Confusion matrix:
# [[18 19  4 ...  0  4  2]
#  [10 68  2 ...  0  4  0]
#  [ 4  2 50 ...  0 12  0]
#  ...
#  [ 1  1  1 ...  9  1  8]
#  [ 4  8 13 ...  2 48  0]
#  [ 1  1  0 ...  3  1 19]]
# 157/157 [==============================] - 0s 1ms/step
# 0.255
#               precision    recall  f1-score   support
#
#            0       0.23      0.18      0.20       100
#            1       0.48      0.68      0.56       100
#            2       0.42      0.50      0.45       100
#            3       0.19      0.16      0.17       100
#            4       0.16      0.18      0.17       100
#            5       0.25      0.28      0.26       100
#            6       0.17      0.21      0.19       100
#            7       0.00      0.00      0.00       100
#            8       0.14      0.09      0.11       100
#            9       0.48      0.49      0.48       100
#           10       0.28      0.34      0.31       100
#           11       0.30      0.36      0.32       100
#           12       0.36      0.32      0.34       100
#           13       0.22      0.29      0.25       100
#           14       0.23      0.21      0.22       100
#           15       0.14      0.17      0.16       100
#           16       0.36      0.44      0.40       100
#           17       0.10      0.07      0.08       100
#           18       0.26      0.32      0.28       100
#           19       0.14      0.26      0.18       100
#           20       0.06      0.02      0.03       100
#           21       0.16      0.10      0.12       100
#           22       0.15      0.17      0.16       100
#           23       0.10      0.12      0.11       100
#           24       0.41      0.39      0.40       100
#           25       0.16      0.12      0.14       100
#           26       0.31      0.24      0.27       100
#           27       0.33      0.28      0.30       100
#           28       0.50      0.31      0.38       100
#           29       0.14      0.10      0.12       100
#           30       0.09      0.06      0.07       100
#           31       0.47      0.49      0.48       100
#           32       0.37      0.48      0.42       100
#           33       0.37      0.34      0.35       100
#           34       0.20      0.14      0.16       100
#           35       0.23      0.38      0.29       100
#           36       0.09      0.13      0.11       100
#           37       0.22      0.13      0.16       100
#           38       0.22      0.24      0.23       100
#           39       0.26      0.22      0.24       100
#           40       0.43      0.46      0.44       100
#           41       0.18      0.30      0.22       100
#           42       0.40      0.48      0.44       100
#           43       0.38      0.41      0.39       100
#           44       0.10      0.17      0.13       100
#           45       0.06      0.03      0.04       100
#           46       0.15      0.13      0.14       100
#           47       0.19      0.09      0.12       100
#           48       0.46      0.48      0.47       100
#           49       0.21      0.19      0.20       100
#
#     accuracy                           0.26      5000
#    macro avg       0.25      0.26      0.25      5000
# weighted avg       0.25      0.26      0.25      5000

# %% [markdown]
# ##### 5b. Investigate different final activation

# %%
# create a function to loop over different final activation functions
def run_final_activation_experiment(final_activations, 
                                    model, 
                                    train_images, 
                                    train_labels, 
                                    test_images, 
                                    test_labels, 
                                    callbacks):

    # create a list to hold investigation results
    results = []
    # loop through the activation functions
    for activation in final_activations:
        print(f'Running experiment with final activation: {activation}')
        # create the model
        model = create_model(final_activation=activation)
        # train the model
        model_history = model.fit(train_images, train_labels, 
                                    batch_size=BATCH_SIZE, 
                                    epochs=EPOCHS, 
                                    validation_split=VALIDATION_SPLIT, 
                                    callbacks=callbacks)

        # evaluate the model
        loss, accuracy = model.evaluate(test_images, test_labels)
        results.append({
            'model': model,
            'history': model_history.history,
            'experiment_variable': activation,
            'loss': loss,
            'accuracy': accuracy
        })
    results = sorted(results, key=lambda x: x['accuracy'], reverse=True)
    return results

# %%
# create a list of final activation functions
final_activations = ['softmax', 'softplus', 'softsign', 'sigmoid', 'tanh', 'relu', 'selu', 'elu', 'linear', 'exponential']

final_activation_results = run_final_activation_experiment(final_activations,
                                                            best_activation_model,
                                                            train_images_block_1,
                                                            train_labels_block_1,
                                                            test_images_block_1,
                                                            test_labels_block_1,
                                                            callbacks)

# print the top result
print(final_activation_results[0])
# Out:
# Running experiment with final activation: softmax
# Epoch 1/30
# 625/625 [==============================] - 3s 4ms/step - loss: 3.9140 - accuracy: 0.0184 - val_loss: 3.9129 - val_accuracy: 0.0166 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9124 - accuracy: 0.0178 - val_loss: 3.9136 - val_accuracy: 0.0172 - lr: 0.0010
# Epoch 3/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9123 - accuracy: 0.0180 - val_loss: 3.9141 - val_accuracy: 0.0166 - lr: 0.0010
# Epoch 4/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9123 - accuracy: 0.0198 - val_loss: 3.9142 - val_accuracy: 0.0166 - lr: 0.0010
# Epoch 5/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9123 - accuracy: 0.0188 - val_loss: 3.9144 - val_accuracy: 0.0166 - lr: 0.0010
# Epoch 6/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9123 - accuracy: 0.0189 - val_loss: 3.9145 - val_accuracy: 0.0166 - lr: 0.0010
# Epoch 7/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9118 - accuracy: 0.0209 - val_loss: 3.9145 - val_accuracy: 0.0166 - lr: 1.0000e-04
# Epoch 8/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9118 - accuracy: 0.0209 - val_loss: 3.9145 - val_accuracy: 0.0166 - lr: 1.0000e-04
# Epoch 9/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9118 - accuracy: 0.0209 - val_loss: 3.9145 - val_accuracy: 0.0166 - lr: 1.0000e-04
# Epoch 10/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9118 - accuracy: 0.0209 - val_loss: 3.9145 - val_accuracy: 0.0166 - lr: 1.0000e-04
# Epoch 11/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9118 - accuracy: 0.0209 - val_loss: 3.9145 - val_accuracy: 0.0166 - lr: 1.0000e-04
# Epoch 12/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9118 - accuracy: 0.0209 - val_loss: 3.9145 - val_accuracy: 0.0166 - lr: 1.0000e-05
# Epoch 13/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9117 - accuracy: 0.0209 - val_loss: 3.9145 - val_accuracy: 0.0166 - lr: 1.0000e-05
# Epoch 14/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9117 - accuracy: 0.0209 - val_loss: 3.9145 - val_accuracy: 0.0166 - lr: 1.0000e-05
# Epoch 15/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9118 - accuracy: 0.0209 - val_loss: 3.9145 - val_accuracy: 0.0166 - lr: 1.0000e-05
# Epoch 16/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.9117 - accuracy: 0.0209 - val_loss: 3.9145 - val_accuracy: 0.0166 - lr: 1.0000e-05
# 157/157 [==============================] - 0s 1ms/step - loss: 3.9121 - accuracy: 0.0200
# Running experiment with final activation: softplus
# Epoch 1/30
# 625/625 [==============================] - 3s 4ms/step - loss: 3.9136 - accuracy: 0.0183 - val_loss: 3.9128 - val_accuracy: 0.0166 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.
30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.7409 - accuracy: 0.2491 - val_loss: 2.9379 - val_accuracy: 0.2150 - lr: 0.0010
# Epoch 15/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.7039 - accuracy: 0.2589 - val_loss: 2.8985 - val_accuracy: 0.2310 - lr: 0.0010
# Epoch 16/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.6702 - accuracy: 0.2643 - val_loss: 2.8975 - val_accuracy: 0.2314 - lr: 0.0010
# Epoch 17/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.6464 - accuracy: 0.2724 - val_loss: 2.9210 - val_accuracy: 0.2276 - lr: 0.0010
# Epoch 18/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.6179 - accuracy: 0.2745 - val_loss: 2.9258 - val_accuracy: 0.2292 - lr: 0.0010
# Epoch 19/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.5836 - accuracy: 0.2857 - val_loss: 2.9122 - val_accuracy: 0.2270 - lr: 0.0010
# Epoch 20/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.5608 - accuracy: 0.2919 - val_loss: 2.9229 - val_accuracy: 0.2342 - lr: 0.0010
# Epoch 21/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.5327 - accuracy: 0.2941 - val_loss: 2.9175 - val_accuracy: 0.2356 - lr: 0.0010
# Epoch 22/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.3285 - accuracy: 0.3458 - val_loss: 2.8568 - val_accuracy: 0.2488 - lr: 1.0000e-04
# Epoch 23/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2871 - accuracy: 0.3577 - val_loss: 2.8612 - val_accuracy: 0.2546 - lr: 1.0000e-04
# Epoch 24/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2677 - accuracy: 0.3608 - val_loss: 2.8766 - val_accuracy: 0.2498 - lr: 1.0000e-04
# Epoch 25/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2527 - accuracy: 0.3629 - val_loss: 2.8795 - val_accuracy: 0.2556 - lr: 1.0000e-04
# Epoch 26/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2403 - accuracy: 0.3666 - val_loss: 2.8868 - val_accuracy: 0.2546 - lr: 1.0000e-04
# Epoch 27/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2284 - accuracy: 0.3711 - val_loss: 2.8950 - val_accuracy: 0.2482 - lr: 1.0000e-04
# Epoch 28/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.1961 - accuracy: 0.3783 - val_loss: 2.8897 - val_accuracy: 0.2522 - lr: 1.0000e-05
# Epoch 29/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.1926 - accuracy: 0.3788 - val_loss: 2.8910 - val_accuracy: 0.2496 - lr: 1.0000e-05
# Epoch 30/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.1906 - accuracy: 0.3796 - val_loss: 2.8911 - val_accuracy: 0.2520 - lr: 1.0000e-05
# 157/157 [==============================] - 0s 1ms/step - loss: 2.9465 - accuracy: 0.2474
# Running experiment with final activation: tanh
# Epoch 1/30
# 625/625 [==============================] - 2s 4ms/step - loss: 8.0312 - accuracy: 0.0194 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 0.0010
# Epoch 3/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 0.0010
# Epoch 4/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 0.0010
# Epoch 5/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 0.0010
# Epoch 6/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 0.0010
# Epoch 7/30
# 625/625 [==============================] - 2s 4ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 1.0000e-04
# Epoch 8/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 1.0000e-04
# Epoch 9/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 1.0000e-04
# Epoch 10/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 1.0000e-04
# Epoch 11/30
# 625/625 [==============================] - 2s 4ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 1.0000e-04
# Epoch 12/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 1.0000e-05
# Epoch 13/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 1.0000e-05
# Epoch 14/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 1.0000e-05
# Epoch 15/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 1.0000e-05
# Epoch 16/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9962 - accuracy: 0.0197 - val_loss: 8.0913 - val_accuracy: 0.0210 - lr: 1.0000e-05
# 157/157 [==============================] - 0s 1ms/step - loss: 7.9849 - accuracy: 0.0198
# Running experiment with final activation: relu
# Epoch 1/30
# 625/625 [==============================] - 2s 4ms/step - loss: 7.9462 - accuracy: 0.0194 - val_loss: 7.8469 - val_accuracy: 0.0184 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 2s 4ms/step - loss: 7.3536 - accuracy: 0.0293 - val_loss: 6.4339 - val_accuracy: 0.0184 - lr: 0.0010
# Epoch 3/30
# 625/625 [==============================] - 2s 3ms/step - loss: 6.3361 - accuracy: 0.0433 - val_loss: 6.3779 - val_accuracy: 0.0508 - lr: 0.0010
# Epoch 4/30
# 625/625 [==============================] - 2s 3ms/step - loss: 6
- lr: 1.0000e-05
# 157/157 [==============================] - 0s 1ms/step - loss: 5.9929 - accuracy: 0.0548
# Running experiment with final activation: selu
# Epoch 1/30
# 625/625 [==============================] - 2s 4ms/step - loss: 8.2559 - accuracy: 0.0176 - val_loss: 7.3253 - val_accuracy: 0.0104 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.8227 - accuracy: 0.0148 - val_loss: 7.0990 - val_accuracy: 0.0156 - lr: 0.0010
# Epoch 3/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.6946 - accuracy: 0.0181 - val_loss: 7.0211 - val_accuracy: 0.0206 - lr: 0.0010
# Epoch 4/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4532 - accuracy: 0.0203 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 0.0010
# Epoch 5/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 0.0010
# Epoch 6/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 0.0010
# Epoch 7/30
# 625/625 [==============================] - 2s 4ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 0.0010
# Epoch 8/30
# 625/625 [==============================] - 2s 4ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 0.0010
# Epoch 9/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 0.0010
# Epoch 10/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 1.0000e-04
# Epoch 11/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 1.0000e-04
# Epoch 12/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 1.0000e-04
# Epoch 13/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 1.0000e-04
# Epoch 14/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 1.0000e-04
# Epoch 15/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 1.0000e-05
# Epoch 16/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 1.0000e-05
# Epoch 17/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 1.0000e-05
# Epoch 18/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 1.0000e-05
# Epoch 19/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2241 - accuracy: 0.0179 - val_loss: 6.9953 - val_accuracy: 0.0206 - lr: 1.0000e-05
# 157/157 [==============================] - 0s 1ms/step - loss: 7.2241 - accuracy: 0.0188
# Running experiment with final activation: elu
# Epoch 1/30
# 625/625 [==============================] - 2s 4ms/step - loss: 8.5712 - accuracy: 0.0194 - val_loss: 7.3490 - val_accuracy: 0.0208 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.7977 - accuracy: 0.0196 - val_loss: 7.2860 - val_accuracy: 0.0208 - lr: 0.0010
# Epoch 3/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.8478 - accuracy: 0.0198 - val_loss: 7.3791 - val_accuracy: 0.0208 - lr: 0.0010
# Epoch 4/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.7540 - accuracy: 0.0198 - val_loss: 6.9663 - val_accuracy: 0.0208 - lr: 0.0010
# Epoch 5/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.8032 - accuracy: 0.0199 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 0.0010
# Epoch 6/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 0.0010
# Epoch 7/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 0.0010
# Epoch 8/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 0.0010
# Epoch 9/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 0.0010
# Epoch 10/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 1.0000e-04
# Epoch 11/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 1.0000e-04
# Epoch 12/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 1.0000e-04
# Epoch 13/30
# 625/625 [==============================] - 2s 4ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 1.0000e-04
# Epoch 14/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 1.0000e-04
# Epoch 15/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 1.0000e-05
# Epoch 16/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 1.0000e-05
# Epoch 17/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 1.0000e-05
# Epoch 18/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 1.0000e-05
# Epoch 19/30
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4675 - accuracy: 0.0188 - val_loss: 7.3692 - val_accuracy: 0.0246 - lr: 1.0000e-05
# 157/157 [==============================] - 0s 1ms/step - loss: 7.1178 - accuracy: 0.0200
# Running experiment with final activation: linear
# Epoch 1/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3469 - accuracy: 0.0198 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 0.0010
# Epoch 3/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 0.0010
# Epoch 4/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 0.0010
# Epoch 5/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 0.0010
# Epoch 6/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 0.0010
# Epoch 7/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 1.0000e-04
# Epoch 8/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 1.0000e-04
# Epoch 9/30
# 625/625 [==============================] - 2s 4ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 1.0000e-04
# Epoch 10/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 1.0000e-04
# Epoch 11/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 1.0000e-04
# Epoch 12/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 1.0000e-05
# Epoch 13/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 1.0000e-05
# Epoch 14/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 1.0000e-05
# Epoch 15/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 1.0000e-05
# Epoch 16/30
# 625/625 [==============================] - 2s 3ms/step - loss: 8.3129 - accuracy: 0.0197 - val_loss: 8.4491 - val_accuracy: 0.0212 - lr: 1.0000e-05
# 157/157 [==============================] - 0s 1ms/step - loss: 8.2396 - accuracy: 0.0200
# Running experiment with final activation: exponential
# Epoch 1/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.6374 - accuracy: 0.0663 - val_loss: 3.4814 - val_accuracy: 0.0914 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.3757 - accuracy: 0.1050 - val_loss: 3.4093 - val_accuracy: 0.1056 - lr: 0.0010
# Epoch 3/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.2495 - accuracy: 0.1391 - val_loss: 3.2266 - val_accuracy: 0.1462 - lr: 0.0010
# Epoch 4/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.1498 - accuracy: 0.1597 - val_loss: 3.1166 - val_accuracy: 0.1740 - lr: 0.0010
# Epoch 5/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.0666 - accuracy: 0.1782 - val_loss: 3.1196 - val_accuracy: 0.1734 - lr: 0.0010
# Epoch 6/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.9900 - accuracy: 0.1931 - val_loss: 3.0429 - val_accuracy: 0.1918 - lr: 0.0010
# Epoch 7/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.9429 - accuracy: 0.2067 - val_loss: 3.0261 - val_accuracy: 0.1920 - lr: 0.0010
# Epoch 8/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.8827 - accuracy: 0.2179 - val_loss: 2.9908 - val_accuracy: 0.2104 - lr: 0.0010
# Epoch 9/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.8469 - accuracy: 0.2268 - val_loss: 2.9733 - val_accuracy: 0.2026 - lr: 0.0010
# Epoch 10/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.8018 - accuracy: 0.2384 - val_loss: 2.9320 - val_accuracy: 0.2174 - lr: 0.0010
# Epoch 11/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.7704 - accuracy: 0.2424 - val_loss: 2.9134 - val_accuracy: 0.2224 - lr: 0.0010
# Epoch 12/30
# 625/625 [==============================] - 2s 4ms/step - loss: 2.7252 - accuracy: 0.2565 - val_loss: 2.8912 - val_accuracy: 0.2280 - lr: 0.0010
# Epoch 13/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.6915 - accuracy: 0.2595 - val_loss: 2.9257 - val_accuracy: 0.2242 - lr: 0.0010
# Epoch 14/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.6567 - accuracy: 0.2722 - val_loss: 2.9294 - val_accuracy: 0.2240 - lr: 0.0010
# Epoch 15/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.6225 - accuracy: 0.2768 - val_loss: 2.9341 - val_accuracy: 0.2126 - lr: 0.0010
# Epoch 16/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.5931 - accuracy: 0.2830 - val_loss: 2.9204 - val_accuracy: 0.2340 - lr: 0.0010
# Epoch 17/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.5577 - accuracy: 0.2939 - val_loss: 2.9170 - val_accuracy: 0.2332 - lr: 0.0010
# Epoch 18/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.3624 - accuracy: 0.3410 - val_loss: 2.8170 - val_accuracy: 0.2624 - lr: 1.0000e-04
# Epoch 19/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.3167 - accuracy: 0.3509 - val_loss: 2.8245 - val_accuracy: 0.2622 - lr: 1.0000e-04
# Epoch 20/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2970 - accuracy: 0.3568 - val_loss: 2.8288 - val_accuracy: 0.2636 - lr: 1.0000e-04
# Epoch 21/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2819 - accuracy: 0.3607 - val_loss: 2.8423 - val_accuracy: 0.2588 - lr: 1.0000e-04
# Epoch 22/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2677 - accuracy: 0.3611 - val_loss: 2.8408 - val_accuracy: 0.2598 - lr: 1.0000e-04
# Epoch 23/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2562 - accuracy: 0.3645 - val_loss: 2.8385 - val_accuracy: 0.2626 - lr: 1.0000e-04
# Epoch 24/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2234 - accuracy: 0.3741 - val_loss: 2.8395 - val_accuracy: 0.2624 - lr: 1.0000e-05
# Epoch 25/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2194 - accuracy: 0.3770 - val_loss: 2.8412 - val_accuracy: 0.2614 - lr: 1.0000e-05
# Epoch 26/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2172 - accuracy: 0.3766 - val_loss: 2.8420 - val_accuracy: 0.2622 - lr: 1.0000e-05
# Epoch 27/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2154 - accuracy: 0.3765 - val_loss: 2.8448 - val_accuracy: 0.2600 - lr: 1.0000e-05
# Epoch 28/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.2140 - accuracy: 0.3765 - val_loss: 2.8430 - val_accuracy: 0.2608 - lr: 1.0000e-05
# Epoch 29/30
# 625/625 [==============================] - 2s 3ms/step - loss: 2.
_images_block_1, test_labels_block_1)
# Out:
# 157/157 [==============================] - 0s 2ms/step - loss: 2.8916 - accuracy: 0.2578
# Test loss:  2.8916125297546387
# Test accuracy:  0.25780001282691956
# 157/157 [==============================] - 0s 2ms/step
# Confusion matrix:
# [[11 18  7 ...  1  8  0]
#  [ 5 71  2 ...  0  6  0]
#  [ 3  3 49 ...  1  6  1]
#  ...
#  [ 3  2  2 ...  6  1  3]
#  [ 6 12  9 ...  0 47  0]
#  [ 0  1  1 ...  2  1 28]]
# 157/157 [==============================] - 0s 1ms/step
# 0.2578
#               precision    recall  f1-score   support
#
#            0       0.17      0.11      0.13       100
#            1       0.47      0.71      0.57       100
#            2       0.45      0.49      0.47       100
#            3       0.18      0.14      0.16       100
#            4       0.12      0.14      0.13       100
#            5       0.26      0.33      0.29       100
#            6       0.24      0.24      0.24       100
#            7       0.10      0.02      0.03       100
#            8       0.16      0.10      0.12       100
#            9       0.44      0.51      0.47       100
#           10       0.30      0.37      0.33       100
#           11       0.32      0.38      0.35       100
#           12       0.34      0.38      0.36       100
#           13       0.23      0.27      0.25       100
#           14       0.22      0.23      0.22       100
#           15       0.14      0.19      0.16       100
#           16       0.38      0.49      0.43       100
#           17       0.15      0.13      0.14       100
#           18       0.34      0.36      0.35       100
#           19       0.21      0.24      0.23       100
#           20       0.05      0.03      0.04       100
#           21       0.10      0.08      0.09       100
#           22       0.14      0.14      0.14       100
#           23       0.06      0.08      0.07       100
#           24       0.36      0.39      0.38       100
#           25       0.20      0.14      0.17       100
#           26       0.28      0.24      0.26       100
#           27       0.28      0.28      0.28       100
#           28       0.38      0.30      0.33       100
#           29       0.11      0.07      0.09       100
#           30       0.22      0.14      0.17       100
#           31       0.48      0.57      0.52       100
#           32       0.33      0.40      0.36       100
#           33       0.39      0.46      0.42       100
#           34       0.20      0.14      0.17       100
#           35       0.22      0.36      0.27       100
#           36       0.08      0.12      0.09       100
#           37       0.18      0.10      0.13       100
#           38       0.20      0.21      0.20       100
#           39       0.25      0.22      0.24       100
#           40       0.38      0.41      0.40       100
#           41       0.13      0.21      0.16       100
#           42       0.34      0.42      0.37       100
#           43       0.39      0.41      0.40       100
#           44       0.09      0.11      0.10       100
#           45       0.20      0.10      0.13       100
#           46       0.13      0.12      0.12       100
#           47       0.13      0.06      0.08       100
#           48       0.51      0.47      0.49       100
#           49       0.31      0.28      0.29       100
#
#     accuracy                           0.26      5000
#    macro avg       0.25      0.26      0.25      5000
# weighted avg       0.25      0.26      0.25      5000

# %% [markdown]
# #### 6. Investigate the use of skip connections in network design.

# %%
# create a model that uses the skip connection, with the best activation and final activation methods
skip_model = create_model(activation=best_activation_method, 
                          loss_function=best_loss_function,
                          final_activation=best_final_activation_method, 
                          use_skip=True)

# train the model
skip_model_history = skip_model.fit(train_images_block_1, train_labels_block_1, 
                                    batch_size=BATCH_SIZE, 
                                    epochs=EPOCHS, 
                                    validation_split=VALIDATION_SPLIT, 
                                    callbacks=callbacks)
# Out:
# Epoch 1/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4751 - accuracy: 0.0198 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 0.0010
# Epoch 3/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 0.0010
# Epoch 4/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 0.0010
# Epoch 5/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 0.0010
# Epoch 6/30
# 625/625 [==============================] - 2s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 0.0010
# Epoch 7/30
# 625/625 [==============================] - 2s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 1.0000e-04
# Epoch 8/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 1.0000e-04
# Epoch 9/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 1.0000e-04
# Epoch 10/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 1.0000e-04
# Epoch 11/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 1.0000e-04
# Epoch 12/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 1.0000e-05
# Epoch 13/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 1.0000e-05
# Epoch 14/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 1.0000e-05
# Epoch 15/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 1.0000e-05
# Epoch 16/30
# 625/625 [==============================] - 3s 4ms/step - loss: 6.4407 - accuracy: 0.0195 - val_loss: 6.4730 - val_accuracy: 0.0218 - lr: 1.0000e-05

# %%
# evaluate the model
evaluate_model(skip_model, skip_model_history.history, test_images_block_1, test_labels_block_1)

# get model loss and accuracy
skip_model_loss, skip_model_accuracy = skip_model.evaluate(test_images_block_1, test_labels_block_1)
# Out:
# 157/157 [==============================] - 0s 2ms/step - loss: 6.4472 - accuracy: 0.0200
# Test loss:  6.447189807891846
# Test accuracy:  0.019999999552965164
# 157/157 [==============================] - 0s 1ms/step
# Confusion matrix:
# [[  0 100   0 ...   0   0   0]
#  [  0 100   0 ...   0   0   0]
#  [  0 100   0 ...   0   0   0]
#  ...
#  [  0 100   0 ...   0   0   0]
#  [  0 100   0 ...   0   0   0]
#  [  0 100   0 ...   0   0   0]]
# 157/157 [==============================] - 0s 1ms/step
# 0.02
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       100
#            1       0.02      1.00      0.04       100
#            2       0.00      0.00      0.00       100
#            3       0.00      0.00      0.00       100
#            4       0.00      0.00      0.00       100
#            5       0.00      0.00      0.00       100
#            6       0.00      0.00      0.00       100
#            7       0.00      0.00      0.00       100
#            8       0.00      0.00      0.00       100
#            9       0.00      0.00      0.00       100
#           10       0.00      0.00      0.00       100
#           11       0.00      0.00      0.00       100
#           12       0.00      0.00      0.00       100
#           13       0.00      0.00      0.00       100
#           14       0.00      0.00      0.00       100
#           15       0.00      0.00      0.00       100
#           16       0.00      0.00      0.00       100
#           17       0.00      0.00      0.00       100
#           18       0.00      0.00      0.00       100
#           19       0.00      0.00      0.00       100
#           20       0.00      0.00      0.00       100
#           21       0.00      0.00      0.00       100
#           22       0.00      0.00      0.00       100
#           23       0.00      0.00      0.00       100
#           24       0.00      0.00      0.00       100
#           25       0.00      0.00      0.00       100
#           26       0.00      0.00      0.00       100
#           27       0.00      0.00      0.00       100
#           28       0.00      0.00      0.00       100
#           29       0.00      0.00      0.00       100
#           30       0.00      0.00      0.00       100
#           31       0.00      0.00      0.00       100
#           32       0.00      0.00      0.00       100
#           33       0.00      0.00      0.00       100
#           34       0.00      0.00      0.00       100
#           35       0.00      0.00      0.00       100
#           36       0.00      0.00      0.00       100
#           37       0.00      0.00      0.00       100
#           38       0.00      0.00      0.00       100
#           39       0.00      0.00      0.00       100
#           40       0.00      0.00      0.00       100
#           41       0.00      0.00      0.00       100
#           42       0.00      0.00      0.00       100
#           43       0.00      0.00      0.00       100
#           44       0.00      0.00      0.00       100
#           45       0.00      0.00      0.00       100
#           46       0.00      0.00      0.00       100
#           47       0.00      0.00      0.00       100
#           48       0.00      0.00      0.00       100
#           49       0.00      0.00      0.00       100
#
#     accuracy                           0.02      5000
#    macro avg       0.00      0.02      0.00      5000
# weighted avg       0.00      0.02      0.00      5000
# /Users/gary.craig/.pyenv/versions/3.11.7/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/gary.craig/.pyenv/versions/3.11.7/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/gary.craig/.pyenv/versions/3.11.7/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 157/157 [==============================] - 0s 2ms/step - loss: 6.4472 - accuracy: 0.0200

# %%
# create a model with all the best parameters
test_model = create_model(activation=best_activation_method, 
                          loss_function=best_loss_function,
                          final_activation=best_final_activation_method, 
                          use_skip=False)

# train the model
test_model_history = test_model.fit(train_images_block_1, train_labels_block_1, 
                                    batch_size=BATCH_SIZE, 
                                    epochs=EPOCHS, 
                                    validation_split=VALIDATION_SPLIT, 
                                    callbacks=callbacks)
# Out:
# Epoch 1/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.5918 - accuracy: 0.0197 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 0.0010
# Epoch 3/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 0.0010
# Epoch 4/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 0.0010
# Epoch 5/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 0.0010
# Epoch 6/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 0.0010
# Epoch 7/30
# 625/625 [==============================] - 2s 4ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 1.0000e-04
# Epoch 8/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 1.0000e-04
# Epoch 9/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 1.0000e-04
# Epoch 10/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 1.0000e-04
# Epoch 11/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 1.0000e-04
# Epoch 12/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 1.0000e-05
# Epoch 13/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 1.0000e-05
# Epoch 14/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 1.0000e-05
# Epoch 15/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 1.0000e-05
# Epoch 16/30
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5338 - accuracy: 0.0200 - val_loss: 3.5943 - val_accuracy: 0.0202 - lr: 1.0000e-05

# %%
# get the model loss and accuracy
test_model_loss, test_model_accuracy = test_model.evaluate(test_images_block_1, test_labels_block_1)
# Out:
# 157/157 [==============================] - 0s 2ms/step - loss: 3.5459 - accuracy: 0.0200

# %% [markdown]
# #### 7. Save the best performing model for the demo notebook and use later.

# %%
# combine the results of the three models, so we can order them by accuracy
combined_results = activation_results + final_activation_results + [{'model': skip_model, 'history': skip_model_history.history, 'accuracy': skip_model_accuracy, 'loss': skip_model_loss, 'experiment_variable': 'skip_layer'}] + [{'model': test_model, 'history': test_model_history.history, 'accuracy': test_model_accuracy, 'loss': test_model_loss, 'experiment_variable': 'all_best_params'}]

# sort the results by accuracy
combined_results = sorted(combined_results, key=lambda x: x['accuracy'], reverse=True)

# save the best model
best_basic_model = combined_results[0]['model']

# save the model to disk
os.makedirs('models/Part2', exist_ok=True)
best_basic_model.save('models/Part2/basic_best_basic_model.keras')

# save the best model history
# save_to_disk(combined_results[0]['history'], 'models/Part2/best_basic_model_history.pkl')

# save the combined results
# os.makedirs('results/Part2', exist_ok=True)
# save_to_disk(combined_results, 'results/Part2/combined_results.pkl')

# %%
# plot a comparison of the combined results
plt.figure(figsize=(10, 6))
for result in combined_results:
    plt.plot(result['history']['accuracy'], label=f"{result['experiment_variable']}: {result['accuracy']:.2f}")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Comparison of Model Accuracy')
plt.legend()
plt.show()

# plot a comparison of the combined results
plt.figure(figsize=(10, 6))
for result in combined_results:
    plt.plot(result['history']['loss'], label=f"{result['experiment_variable']}: {result['loss']:.2f}")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Comparison of Model Loss')
plt.legend()
plt.show()

# evaluate the best model
evaluate_model(best_basic_model, combined_results[0]['history'], test_images_block_1, test_labels_block_1)
# Out:
# 157/157 [==============================] - 0s 2ms/step - loss: 2.9114 - accuracy: 0.2918
# Test loss:  2.911419630050659
# Test accuracy:  0.29179999232292175
# 157/157 [==============================] - 0s 1ms/step
# Confusion matrix:
# [[20 19  5 ...  2  4  0]
#  [ 6 65  2 ...  1  5  2]
#  [ 3  1 52 ...  1 10  0]
#  ...
#  [ 2  4  0 ... 16  2  1]
#  [ 6  9 15 ...  2 43  1]
#  [ 1  0  0 ...  2  2 23]]
# 157/157 [==============================] - 0s 1ms/step
# 0.2918
#               precision    recall  f1-score   support
#
#            0       0.23      0.20      0.21       100
#            1       0.48      0.65      0.55       100
#            2       0.44      0.52      0.48       100
#            3       0.24      0.15      0.18       100
#            4       0.18      0.23      0.20       100
#            5       0.25      0.33      0.29       100
#            6       0.26      0.28      0.27       100
#            7       0.11      0.10      0.11       100
#            8       0.19      0.14      0.16       100
#            9       0.51      0.48      0.49       100
#           10       0.29      0.29      0.29       100
#           11       0.33      0.42      0.37       100
#           12       0.40      0.40      0.40       100
#           13       0.32      0.35      0.33       100
#           14       0.28      0.31      0.29       100
#           15       0.26      0.25      0.25       100
#           16       0.44      0.51      0.47       100
#           17       0.13      0.11      0.12       100
#           18       0.39      0.33      0.36       100
#           19       0.27      0.31      0.29       100
#           20       0.11      0.05      0.07       100
#           21       0.15      0.15      0.15       100
#           22       0.18      0.19      0.18       100
#           23       0.13      0.15      0.14       100
#           24       0.39      0.46      0.42       100
#           25       0.21      0.20      0.20       100
#           26       0.25      0.24      0.24       100
#           27       0.35      0.31      0.33       100
#           28       0.36      0.31      0.34       100
#           29       0.14      0.10      0.12       100
#           30       0.23      0.16      0.19       100
#           31       0.49      0.50      0.49       100
#           32       0.39      0.52      0.45       100
#           33       0.42      0.42      0.42       100
#           34       0.21      0.15      0.17       100
#           35       0.27      0.39      0.32       100
#           36       0.11      0.13      0.12       100
#           37       0.21      0.16      0.18       100
#           38       0.23      0.22      0.22       100
#           39       0.29      0.26      0.27       100
#           40       0.44      0.52      0.48       100
#           41       0.27      0.35      0.31       100
#           42       0.37      0.49      0.42       100
#           43       0.38      0.38      0.38       100
#           44       0.14      0.14      0.14       100
#           45       0.28      0.21      0.24       100
#           46       0.25      0.25      0.25       100
#           47       0.18      0.16      0.17       100
#           48       0.48      0.43      0.46       100
#           49       0.32      0.23      0.27       100
#
#     accuracy                           0.29      5000
#    macro avg       0.28      0.29      0.29      5000
# weighted avg       0.28      0.29      0.29      5000

# %% [markdown]
# #### Autoencoder Modelling: For Block 1 Images
# Building on your best performing model to this point, construct an autoencoder model to attempt
# to reproduce input images. Discuss the appropriate use of loss functions and metrics for
# evaluation.
# Save the model notebook for the demo notebook and use later.

# %%
# load the best model
from tensorflow.keras.models import load_model
best_basic_model = load_model('models/Part2/basic_best_basic_model.keras')

# %%
from tensorflow.keras.layers import Dense, Reshape, Input
from tensorflow.keras.models import Model

def create_decoder(input_dim=50, 
                   activation='relu', 
                   final_activation='sigmoid',
                   output_shape=(32, 32, 3)):
    # Input latent representation
    latent_inputs = Input(shape=(input_dim,))
    
    # First hidden layer
    dense_one = Dense(32, activation=activation)(latent_inputs)
    # Second hidden layer
    dense_two = Dense(64, activation=activation)(dense_one)
    # Third hidden layer
    dense_three = Dense(128, activation=activation)(dense_two)
    # Fourth hidden layer
    dense_four = Dense(256, activation=activation)(dense_three)
    # Fifth hidden layer
    dense_five = Dense(512, activation=activation)(dense_four)

    # Output layer (reshaping back to original input shape)
    output_layer = Dense(output_shape[0] * output_shape[1] * output_shape[2], 
                         activation=final_activation)(dense_five)
    outputs = Reshape(output_shape)(output_layer)

    decoder = Model(latent_inputs, outputs)
    return decoder

# %%
# def create_decoder(input_dim=50, 
#                    activation='relu',
#                    optimizer='adam',
#                    final_activation='sigmoid',
#                    loss_function='mse'):
#     """
#     Creates a decoder model to reconstruct the original image from encoded features.
    
#     Parameters:
#     - input_dim: The dimensionality of the encoded input vector.
#     - activation: Activation function for hidden layers.
#     - optimizer: Optimizer to use for compiling the model.
#     - final_activation: Activation function for the output layer.
#     - loss_function: Loss function to use for compiling the model.
    
#     Returns:
#     - A compiled Keras decoder model.
#     """
#     # Input layer for the encoded vector
#     inputs = Input(shape=(input_dim,))
    
#     # Dense layers to expand the encoded vector back
#     dense1 = Dense(256, activation=activation)(inputs)
#     dense2 = Dense(128, activation=activation)(dense1)
#     dense3 = Dense(4 * 4 * 128, activation=activation)(dense2)
    
#     # Reshape to match the feature map shape
#     reshaped = Reshape((4, 4, 128))(dense3)
    
#     # Decoder layers (adjusted for 32x32x3 output)
#     conv1_transpose = Conv2DTranspose(128, (3, 3), activation=activation, padding='same')(reshaped)
#     up1 = UpSampling2D((2, 2))(conv1_transpose)  # 8x8
    
#     conv2_transpose = Conv2DTranspose(64, (3, 3), activation=activation, padding='same')(up1)
#     up2 = UpSampling2D((2, 2))(conv2_transpose)  # 16x16
    
#     conv3_transpose = Conv2DTranspose(32, (3, 3), activation=activation, padding='same')(up2)
#     up3 = UpSampling2D((2, 2))(conv3_transpose)  # 32x32
    
#     # Final convolution layer to match the original image dimensions
#     output = Conv2D(3, (3, 3), activation=final_activation, padding='same')(up3)
    
#     # Create and compile the model
#     decoder = Model(inputs, output)
#     decoder.compile(optimizer=optimizer, loss=loss_function)
    
#     return decoder

# %%
# load the best basic model, from disk
# encoder_model = load_model('models/Part1/best_basic_model.keras')

# %%
# create an autoencoder model to reconstruct the images based on the best basic model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape

decoder = create_decoder(input_dim=50)
decoder.summary()
# Out:
# Model: "model_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_21 (InputLayer)       [(None, 50)]              0
#
#  dense_121 (Dense)           (None, 32)                1632
#
#  dense_122 (Dense)           (None, 64)                2112
#
#  dense_123 (Dense)           (None, 128)               8320
#
#  dense_124 (Dense)           (None, 256)               33024
#
#  dense_125 (Dense)           (None, 512)               131584
#
#  dense_126 (Dense)           (None, 3072)              1575936
#
#  reshape (Reshape)           (None, 32, 32, 3)         0
#
# =================================================================
# Total params: 1752608 (6.69 MB)
# Trainable params: 1752608 (6.69 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape

# # Input to autoencoder
# autoencoder_input = best_basic_model.input
# # Pass encoder's output to decoder
# autoencoder_output = decoder(best_basic_model.output)

# # Combine into an autoencoder model
# autoencoder = Model(autoencoder_input, autoencoder_output)
# autoencoder.compile(optimizer='adam', loss='mse')

# Combine encoder and decoder into an autoencoder
encoded_input = best_basic_model.input  # Input to the encoder
encoded_output = best_basic_model(encoded_input)  # Encoder's output
decoded_output = decoder(encoded_output)  # Pass through the decoder

# Create the autoencoder model
autoencoder = Model(inputs=encoded_input, outputs=decoded_output)

# Compile the autoencoder
autoencoder.compile(optimizer='adam', loss='mse')

# Display the autoencoder summary
autoencoder.summary()
# Out:
# Model: "model_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  model_2 (Functional)        (None, 50)                1749586
#
#  model_20 (Functional)       (None, 32, 32, 3)         1752608
#
# =================================================================
# Total params: 3502194 (13.36 MB)
# Trainable params: 3502194 (13.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# train the autoencoder model
autoencoder_history = autoencoder.fit(train_images_block_1, train_images_block_1, 
                                      batch_size=BATCH_SIZE, 
                                      epochs=EPOCHS, 
                                      validation_split=VALIDATION_SPLIT, 
                                      callbacks=callbacks)

# save the autoencoder model
autoencoder.save('models/Part2/basic_autoencoder_model.keras')

# evaluate the autoencoder model
# loss, accuracy = autoencoder.evaluate(test_images_block_1, test_images_block_1)
# print(f'Autoencoder Test Loss: {loss}')
# print(f'Autoencoder Test Accuracy: {accuracy}')
# Out:
# Epoch 1/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.0302 - val_loss: 0.0305 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0300 - val_loss: 0.0302 - lr: 0.0010
# Epoch 3/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0298 - val_loss: 0.0301 - lr: 0.0010
# Epoch 4/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0284 - val_loss: 0.0282 - lr: 0.0010
# Epoch 5/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.0276 - val_loss: 0.0277 - lr: 0.0010
# Epoch 6/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0273 - val_loss: 0.0273 - lr: 0.0010
# Epoch 7/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.0269 - val_loss: 0.0261 - lr: 0.0010
# Epoch 8/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.0256 - val_loss: 0.0258 - lr: 0.0010
# Epoch 9/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0253 - val_loss: 0.0257 - lr: 0.0010
# Epoch 10/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0251 - val_loss: 0.0256 - lr: 0.0010
# Epoch 11/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.0250 - val_loss: 0.0255 - lr: 0.0010
# Epoch 12/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0249 - val_loss: 0.0252 - lr: 0.0010
# Epoch 13/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.0243 - val_loss: 0.0243 - lr: 0.0010
# Epoch 14/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0238 - val_loss: 0.0237 - lr: 0.0010
# Epoch 15/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.0231 - val_loss: 0.0233 - lr: 0.0010
# Epoch 16/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0226 - val_loss: 0.0230 - lr: 0.0010
# Epoch 17/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0225 - val_loss: 0.0229 - lr: 0.0010
# Epoch 18/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0224 - val_loss: 0.0230 - lr: 0.0010
# Epoch 19/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0222 - val_loss: 0.0229 - lr: 0.0010
# Epoch 20/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0222 - val_loss: 0.0232 - lr: 0.0010
# Epoch 21/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.0221 - val_loss: 0.0227 - lr: 0.0010
# Epoch 22/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0220 - val_loss: 0.0226 - lr: 0.0010
# Epoch 23/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0219 - val_loss: 0.0230 - lr: 0.0010
# Epoch 24/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0219 - val_loss: 0.0225 - lr: 0.0010
# Epoch 25/30
# 625/625 [==============================] - 6s 9ms/step - loss: 0.0218 - val_loss: 0.0226 - lr: 0.0010
# Epoch 26/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.0217 - val_loss: 0.0226 - lr: 0.0010
# Epoch 27/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.0217 - val_loss: 0.0230 - lr: 0.0010
# Epoch 28/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0216 - val_loss: 0.0228 - lr: 0.0010
# Epoch 29/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0216 - val_loss: 0.0223 - lr: 0.0010
# Epoch 30/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.0215 - val_loss: 0.0225 - lr: 0.0010

# %%
# display the decoded images
decoded_images = autoencoder.predict(test_images_block_1)

# display the first 10 images
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 4))
for i in range(10):
    # display original
    ax = plt.subplot(2, 10, i + 1)
    plt.imshow(test_images_block_1[i])
    # get the label names from the label encoder
    ax.set_title(le.inverse_transform([np.argmax(test_labels_block_1[i])]))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, 10, i + 1 + 10)
    plt.imshow(decoded_images[i])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# #### Transfer Learning for Block 2 Images
# Using the two models saved above, investigate the use of transfer learning to build a network for
# Block 2 images. Compare results for Transfer Learning based implementations to those for afromscratch implementation equivalent to the transferred model.

# %%
# create defintion that uses the best_basic_model and the autoencoder model to build a new model
